# %% [raw]
# import pandas as pd
# import numpy as np

# %%
data_name = f"주택도시보증공사_전국 신규 민간아파트 분양가격 동향_20210831.csv"

# %%
data_name
# Out:
# '주택도시보증공사_전국 신규 민간아파트 분양가격 동향_20210831.csv'

# %%
data_name = pd.read_csv(data_name, encoding = "cp949")

# %%
data_name
# Out:
#      지역명                     규모구분    연도   월 분양가격(제곱미터)
# 0     서울                     모든면적  2015  10       5841
# 1     서울            전용면적 60제곱미터이하  2015  10       5652
# 2     서울   전용면적 60제곱미터초과 85제곱미터이하  2015  10       5882
# 3     서울  전용면적 85제곱미터초과 102제곱미터이하  2015  10       5721
# 4     서울           전용면적 102제곱미터초과  2015  10       5879
# ...   ..                      ...   ...  ..        ...
# 6030  제주                     모든면적  2021   8       8356
# 6031  제주            전용면적 60제곱미터이하  2021   8        NaN
# 6032  제주   전용면적 60제곱미터초과 85제곱미터이하  2021   8       8410
# 6033  제주  전용면적 85제곱미터초과 102제곱미터이하  2021   8        NaN
# 6034  제주           전용면적 102제곱미터초과  2021   8       7727
#
# [6035 rows x 5 columns]

# %%
data_name.head()
# Out:
#   지역명                     규모구분    연도   월 분양가격(제곱미터)
# 0  서울                     모든면적  2015  10       5841
# 1  서울            전용면적 60제곱미터이하  2015  10       5652
# 2  서울   전용면적 60제곱미터초과 85제곱미터이하  2015  10       5882
# 3  서울  전용면적 85제곱미터초과 102제곱미터이하  2015  10       5721
# 4  서울           전용면적 102제곱미터초과  2015  10       5879

# %%
data_name.tail()
# Out:
#      지역명                     규모구분    연도  월 분양가격(제곱미터)
# 6030  제주                     모든면적  2021  8       8356
# 6031  제주            전용면적 60제곱미터이하  2021  8        NaN
# 6032  제주   전용면적 60제곱미터초과 85제곱미터이하  2021  8       8410
# 6033  제주  전용면적 85제곱미터초과 102제곱미터이하  2021  8        NaN
# 6034  제주           전용면적 102제곱미터초과  2021  8       7727

# %%
df_last = data_name

# %%
file_name = f"전국 평균 분양가격(2013년 9월부터 2015년 8월까지).csv"

# %%
file_name
# Out:
# '전국 평균 분양가격(2013년 9월부터 2015년 8월까지).csv'

# %%
file_name = pd.read_csv(file_name, encoding="cp949")

# %%
file_name
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0   서울     18189    17925    17925    18016    18098    19446    18867
# 1   부산      8111     8111     9078     8965     9402     9501     9453
# 2   대구      8080     8080     8077     8101     8267     8274     8360
# 3   인천     10204    10204    10408    10408    10000     9844    10058
# 4   광주      6098     7326     7611     7346     7346     7523     7659
# 5   대전      8321     8321     8321     8341     8341     8341     8333
# 6   울산      8090     8090     8090     8153     8153     8153     8153
# 7   경기     10855    10855    10791    10784    10876    10646    10266
# 8   세종      7601     7600     7532     7814     7908     7934     8067
# 9   강원      6230     6230     6230     6141     6373     6350     6350
# 10  충북      6589     6589     6611     6625     6678     6598     6587
# 11  충남      6365     6365     6379     6287     6552     6591     6644
# ...

# %%
file_name.head()
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
# 1  부산      8111     8111     9078     8965     9402     9501     9453
# 2  대구      8080     8080     8077     8101     8267     8274     8360
# 3  인천     10204    10204    10408    10408    10000     9844    10058
# 4  광주      6098     7326     7611     7346     7346     7523     7659
#
#    2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 0    18742    19274  ...     20242     20269    20670    20670    19415
# 1     9457     9411  ...      9208      9208     9204     9235     9279
# 2     8360     8370  ...      8439      8253     8327     8416     8441
# 3     9974     9973  ...     10020     10020    10017     9876     9876
# 4     7612     7622  ...      7752      7748     7752     7756     7861
#
#    2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    18842    18367    18374    18152    18443
# ...

# %%
file_name.tail()
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 12  전북      6282     6281     5946     5966     6277     6306     6351
# 13  전남      5678     5678     5678     5696     5736     5656     5609
# 14  경북      6168     6168     6234     6317     6412     6409     6554
# 15  경남      6473     6485     6502     6610     6599     6610     6615
# 16  제주      7674     7900     7900     7900     7900     7900     7914
#
#     2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 12     6319     6436  ...      6583      6583     6583     6583     6542
# 13     5780     5685  ...      5768      5784     5784     5833     5825
# 14     6556     6563  ...      6881      6989     6992     6953     6997
# 15     6613     6606  ...      7125      7332     7592     7588     7668
# 16     7914     7914  ...      7724      7739     7739     7739     7826
#
#     2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 12     6551     6556     6601     6750     6580
# ...

# %%
#df_last = pd.concat([data_name,file_name])

# %%
df_first = file_name

# %%
df_last.tail()
# Out:
#      지역명                     규모구분    연도  월 분양가격(제곱미터)
# 6030  제주                     모든면적  2021  8       8356
# 6031  제주            전용면적 60제곱미터이하  2021  8        NaN
# 6032  제주   전용면적 60제곱미터초과 85제곱미터이하  2021  8       8410
# 6033  제주  전용면적 85제곱미터초과 102제곱미터이하  2021  8        NaN
# 6034  제주           전용면적 102제곱미터초과  2021  8       7727

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6035 entries, 0 to 6034
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지역명         6035 non-null   object
#  1   규모구분        6035 non-null   object
#  2   연도          6035 non-null   int64
#  3   월           6035 non-null   int64
#  4   분양가격(제곱미터)  5564 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 235.9+ KB

# %%
df_first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역        17 non-null     object
#  1   2013년12월  17 non-null     int64
#  2   2014년1월   17 non-null     int64
#  3   2014년2월   17 non-null     int64
#  4   2014년3월   17 non-null     int64
#  5   2014년4월   17 non-null     int64
#  6   2014년5월   17 non-null     int64
#  7   2014년6월   17 non-null     int64
#  8   2014년7월   17 non-null     int64
#  9   2014년8월   17 non-null     int64
#  10  2014년9월   17 non-null     int64
#  11  2014년10월  17 non-null     int64
#  12  2014년11월  17 non-null     int64
#  13  2014년12월  17 non-null     int64
#  14  2015년1월   17 non-null     int64
#  15  2015년2월   17 non-null     int64
#  16  2015년3월   17 non-null     int64
#  17  2015년4월   17 non-null     int64
#  18  2015년5월   17 non-null     int64
#  19  2015년6월   17 non-null     int64
# ...

# %%
True == 1, False == 0
# Out:
# (True, True)

# %%
df_last.isnull().sum() #isnull()을 통해 결측치 보기 #sum해서 결측치 합계 구하기
# Out:
# 지역명             0
# 규모구분            0
# 연도              0
# 월               0
# 분양가격(제곱미터)    471
# dtype: int64

# %%
#isna를 통해 결측치 구하기
df_last.isna().sum()
# Out:
# 지역명             0
# 규모구분            0
# 연도              0
# 월               0
# 분양가격(제곱미터)    471
# dtype: int64

# %%
df_last
# Out:
#      지역명                     규모구분    연도   월 분양가격(제곱미터)
# 0     서울                     모든면적  2015  10       5841
# 1     서울            전용면적 60제곱미터이하  2015  10       5652
# 2     서울   전용면적 60제곱미터초과 85제곱미터이하  2015  10       5882
# 3     서울  전용면적 85제곱미터초과 102제곱미터이하  2015  10       5721
# 4     서울           전용면적 102제곱미터초과  2015  10       5879
# ...   ..                      ...   ...  ..        ...
# 6030  제주                     모든면적  2021   8       8356
# 6031  제주            전용면적 60제곱미터이하  2021   8        NaN
# 6032  제주   전용면적 60제곱미터초과 85제곱미터이하  2021   8       8410
# 6033  제주  전용면적 85제곱미터초과 102제곱미터이하  2021   8        NaN
# 6034  제주           전용면적 102제곱미터초과  2021   8       7727
#
# [6035 rows x 5 columns]

# %%
df_first
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0   서울     18189    17925    17925    18016    18098    19446    18867
# 1   부산      8111     8111     9078     8965     9402     9501     9453
# 2   대구      8080     8080     8077     8101     8267     8274     8360
# 3   인천     10204    10204    10408    10408    10000     9844    10058
# 4   광주      6098     7326     7611     7346     7346     7523     7659
# 5   대전      8321     8321     8321     8341     8341     8341     8333
# 6   울산      8090     8090     8090     8153     8153     8153     8153
# 7   경기     10855    10855    10791    10784    10876    10646    10266
# 8   세종      7601     7600     7532     7814     7908     7934     8067
# 9   강원      6230     6230     6230     6141     6373     6350     6350
# 10  충북      6589     6589     6611     6625     6678     6598     6587
# 11  충남      6365     6365     6379     6287     6552     6591     6644
# ...

# %%
#분양가격이 object 타입으로 되어 있어, 연산을 하기 편리하지 않아서 수치 타입으로 바꾸어 준다.
df_last["분양가격"] = pd.to_numeric(df_last["분양가격(제곱미터)"], errors='coerce')
df_last["분양가격"].head(1)#float인 수치인 데이터형식으로 바꾸어주었다.
# Out:
# 0    5841.0
# Name: 분양가격, dtype: float64

# %%
#df_first에 있는 분양가격과 df_last에 있는 분양 가격 단위 맞추어 주기
df_last["평당분양가격"] = df_last["분양가격"]*3.3

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6035 entries, 0 to 6034
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지역명         6035 non-null   object
#  1   규모구분        6035 non-null   object
#  2   연도          6035 non-null   int64
#  3   월           6035 non-null   int64
#  4   분양가격(제곱미터)  5564 non-null   object
#  5   분양가격        5548 non-null   float64
#  6   평당분양가격      5548 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 330.2+ KB

# %%
#요약 결과가 다르다. object 타입과 수치데이터 타입 일떄, 비교
#unique한 값은 중복되지 않은 값을 뜻한다.
#top 가장 빈번하게 등장하는 값은 무엇이냐
#freq 가장 빈번하게 등장하는 값이 얼마나 등장하느냐
df_last["분양가격(제곱미터)"].describe()
# Out:
# count     5564
# unique    2196
# top       3395
# freq        18
# Name: 분양가격(제곱미터), dtype: object

# %%
#요약 결과가 다르다. object 타입과 수치데이터 타입 일떄, 비교
df_last["분양가격"].describe()
# Out:
# count     5548.000000
# mean      3450.018205
# std       1406.599626
# min       1868.000000
# 25%       2567.000000
# 50%       3064.000000
# 75%       3911.000000
# max      13835.000000
# Name: 분양가격, dtype: float64

# %%
#전용면적이라는 반복되는 이름을 제거하여 데이터를 값을 줄이는 과정
df_last["규모구분"].unique()
# Out:
# array(['모든면적', '전용면적 60제곱미터이하', '전용면적 60제곱미터초과 85제곱미터이하',
#        '전용면적 85제곱미터초과 102제곱미터이하', '전용면적 102제곱미터초과'], dtype=object)

# %%
#전용면적이라는 반복되는 이름을 제거하여 데이터를 값을 줄이는 과정
#
df_last["전용면적"] = df_last["규모구분"].str.replace("전용면적","")
df_last["전용면적"] = df_last["전용면적"].str.replace("초과","~")
df_last["전용면적"] = df_last["전용면적"].str.replace("이하","")
df_last["전용면적"] = df_last["전용면적"].str.replace(" ","")
df_last["전용면적"]
# Out:
# 0                 모든면적
# 1               60제곱미터
# 2        60제곱미터~85제곱미터
# 3       85제곱미터~102제곱미터
# 4             102제곱미터~
#              ...
# 6030              모든면적
# 6031            60제곱미터
# 6032     60제곱미터~85제곱미터
# 6033    85제곱미터~102제곱미터
# 6034          102제곱미터~
# Name: 전용면적, Length: 6035, dtype: object

# %%
#사용하지 않는 컬럼 제거하기 #메모리 사용량을 줄일 수 있다.
df_last = df_last.drop(["규모구분","분양가격(제곱미터)"],axis=1)
df_last
# Out:
#      지역명    연도   월    분양가격   평당분양가격            전용면적
# 0     서울  2015  10  5841.0  19275.3            모든면적
# 1     서울  2015  10  5652.0  18651.6          60제곱미터
# 2     서울  2015  10  5882.0  19410.6   60제곱미터~85제곱미터
# 3     서울  2015  10  5721.0  18879.3  85제곱미터~102제곱미터
# 4     서울  2015  10  5879.0  19400.7        102제곱미터~
# ...   ..   ...  ..     ...      ...             ...
# 6030  제주  2021   8  8356.0  27574.8            모든면적
# 6031  제주  2021   8     NaN      NaN          60제곱미터
# 6032  제주  2021   8  8410.0  27753.0   60제곱미터~85제곱미터
# 6033  제주  2021   8     NaN      NaN  85제곱미터~102제곱미터
# 6034  제주  2021   8  7727.0  25499.1        102제곱미터~
#
# [6035 rows x 6 columns]

# %% [markdown]
# #groupby 로 데이터 집계하기
# groupby를 통해 데이터를 그룹화해서 연산하기
#
# #지역명으로 분양가격의 평균을 구하고 막대그래프(bar)로 시각화 하기.
#
# #df.groupby(["인덱스로 사용할 컬럼명"])["계산할 컬럼 값"].연산()

# %%
df_last.groupby(["지역명"])["평당분양가격"].mean() #평균값
# Out:
# 지역명
# 강원     8562.691837
# 경기    13775.231831
# 경남     9754.237283
# 경북     8946.151351
# 광주    11052.022222
# 대구    12969.009538
# 대전    10516.325000
# 부산    12510.950704
# 서울    25185.422380
# 세종    10261.405000
# 울산    11156.424783
# 인천    12893.852137
# 전남     8155.968966
# 전북     7984.194872
# 제주    12698.411498
# 충남     8534.084821
# 충북     7882.213598
# Name: 평당분양가격, dtype: float64

# %%
#전용면적으로 분양가격의 평균을 구합니다.
df_last.groupby(["전용면적"])["평당분양가격"].mean()
# Out:
# 전용면적
# 102제곱미터~          12228.519907
# 60제곱미터            11011.521770
# 60제곱미터~85제곱미터     10969.213877
# 85제곱미터~102제곱미터    11884.432017
# 모든면적              10990.281795
# Name: 평당분양가격, dtype: float64

# %%
# 두 가지의 인데스로 평당분양가격의 평균 구하기
df_last.groupby(["전용면적","지역명"])["평당분양가격"].mean()
#unstack() : 끝에 있는 인덱스가 columns로 와서 더 이쁘게 보여준다.
#.round() : 뒤에 지저분한 소수점이 한자리수로 정리되어 더 이쁘게 보여준다.
# Out:
# 전용면적      지역명
# 102제곱미터~  강원      9641.763380
#           경기     15200.171831
#           경남     10376.489063
#           경북      9695.254412
#           광주     12347.746552
#                      ...
# 모든면적      전남      7825.833803
#           전북      7634.387324
#           제주     12845.505634
#           충남      8145.469014
#           충북      7497.181690
# Name: 평당분양가격, Length: 85, dtype: float64

# %%
df_last.groupby(["전용면적","지역명"])["평당분양가격"].mean().unstack().round()
# Out:
# 지역명                 강원       경기       경남      경북       광주       대구       대전  \
# 전용면적
# 102제곱미터~        9642.0  15200.0  10376.0  9695.0  12348.0  13977.0  14875.0
# 60제곱미터          8273.0  13480.0   9007.0  8516.0  10320.0  12818.0   9819.0
# 60제곱미터~85제곱미터   8011.0  12994.0   9063.0  8550.0  10706.0  12770.0  10162.0
# 85제곱미터~102제곱미터  8903.0  14171.0  11265.0  9611.0  11587.0  12452.0   9078.0
# 모든면적            8041.0  13031.0   9100.0  8568.0  10787.0  12762.0  10214.0
#
# 지역명                  부산       서울       세종       울산       인천      전남      전북  \
# 전용면적
# 102제곱미터~        13340.0  25180.0  10460.0  11523.0  15112.0  9054.0  8422.0
# 60제곱미터          11966.0  24677.0  10017.0  10920.0  12211.0  7634.0  7851.0
# 60제곱미터~85제곱미터   12387.0  23926.0  10230.0  11402.0  12355.0  7830.0  7602.0
# 85제곱미터~102제곱미터  12422.0  28091.0  10252.0   9622.0  12641.0  8442.0  8436.0
# 모든면적            12439.0  24053.0  10274.0  11323.0  12275.0  7826.0  7634.0
#
# ...

# %%
#연도, 지역명으로 평당분양가격의 평균을 구합니다.
g = df_last.groupby(["연도", "지역명"])["평당분양가격"].mean().unstack().T
g
# Out:
# 연도        2015          2016          2017          2018          2019  \
# 지역명
# 강원    7188.060   7162.903846   7318.850000   8219.255000   8934.475000
# 경기   11060.940  11684.970000  12296.185000  14258.420000  15665.540000
# 경남    8459.220   8496.730000   8806.600000   9327.670000  10697.615789
# 경북    7464.160   7753.405000   8288.063793   8680.776923   9050.250000
# 광주    7916.700   9190.683333   9599.700000   9526.953333  12111.675000
# 대구    9018.900  10282.030000  12191.972222  12139.252632  14081.650000
# 대전    8190.600   8910.733333   9912.910526  10234.106667  12619.200000
# 부산   10377.400  10743.535000  11637.615000  12889.965000  13537.865000
# 서울   20315.680  21753.435000  21864.095000  23202.245000  28286.830000
# 세종    8765.020   8857.805000   9132.945763  10340.463158  11299.394118
# 울산    9367.600   9582.574138  10630.160870  10241.400000  10216.250000
# 인천   10976.020  11099.055000  11672.430000  11881.532143  13249.775000
# ...

# %% [markdown]
# pivot table 로 위에서 한 groupby로 한 작업 똑같이 해보기

# %%
pd.pivot_table(df_last, index=["지역명"], values=["평당분양가격"], aggfunc="mean")
#groupby 와 pivot table의 차이는 연산의 결과가 
#series로 나오는냐 Dataframe형식으로 나오느냐 차이다.
# Out:
#            평당분양가격
# 지역명
# 강원    8562.691837
# 경기   13775.231831
# 경남    9754.237283
# 경북    8946.151351
# 광주   11052.022222
# 대구   12969.009538
# 대전   10516.325000
# 부산   12510.950704
# 서울   25185.422380
# 세종   10261.405000
# 울산   11156.424783
# 인천   12893.852137
# 전남    8155.968966
# 전북    7984.194872
# 제주   12698.411498
# 충남    8534.084821
# 충북    7882.213598

# %%
#둘의 차이점 보기
#df_last.groupby(["전용면적"])["평당분양가격"].mean()  >>series 형태
pd.pivot_table(df_last, index="전용면적", values="평당분양가격")
# Out:
#                       평당분양가격
# 전용면적
# 102제곱미터~        12228.519907
# 60제곱미터          11011.521770
# 60제곱미터~85제곱미터   10969.213877
# 85제곱미터~102제곱미터  11884.432017
# 모든면적            10990.281795

# %%
#둘이 비교
#df_last.groupby(["전용면적","지역명"])["평당분양가격"].mean().unstack().round()
df_last.pivot_table(index="전용면적", columns = "지역명", values="평당분양가격" ).round()
# Out:
# 지역명                 강원       경기       경남      경북       광주       대구       대전  \
# 전용면적
# 102제곱미터~        9642.0  15200.0  10376.0  9695.0  12348.0  13977.0  14875.0
# 60제곱미터          8273.0  13480.0   9007.0  8516.0  10320.0  12818.0   9819.0
# 60제곱미터~85제곱미터   8011.0  12994.0   9063.0  8550.0  10706.0  12770.0  10162.0
# 85제곱미터~102제곱미터  8903.0  14171.0  11265.0  9611.0  11587.0  12452.0   9078.0
# 모든면적            8041.0  13031.0   9100.0  8568.0  10787.0  12762.0  10214.0
#
# 지역명                  부산       서울       세종       울산       인천      전남      전북  \
# 전용면적
# 102제곱미터~        13340.0  25180.0  10460.0  11523.0  15112.0  9054.0  8422.0
# 60제곱미터          11966.0  24677.0  10017.0  10920.0  12211.0  7634.0  7851.0
# 60제곱미터~85제곱미터   12387.0  23926.0  10230.0  11402.0  12355.0  7830.0  7602.0
# 85제곱미터~102제곱미터  12422.0  28091.0  10252.0   9622.0  12641.0  8442.0  8436.0
# 모든면적            12439.0  24053.0  10274.0  11323.0  12275.0  7826.0  7634.0
#
# ...

# %%
#연도, 지역명으로 평당분양가격의 평균을 구합니다.
g = df_last.groupby(["연도", "지역명"])["평당분양가격"].mean().unstack().T
p = df_last.pivot_table(index=["연도","지역명"], values="평당분양가격")
p
# Out:
#                 평당분양가격
# 연도   지역명
# 2015 강원    7188.060000
#      경기   11060.940000
#      경남    8459.220000
#      경북    7464.160000
#      광주    7916.700000
# ...                ...
# 2021 전남    9930.800000
#      전북    8801.861538
#      제주   22619.469231
#      충남    9645.639474
#      충북    8805.142500
#
# [119 rows x 1 columns]

# %% [markdown]
# 최근 데이터 시각화 하기
#
# 데이터 시각화를 우한 폰트 설정
#
# (한글 폰트 사용을 위해 matplotlib의 pyplot을 plt라는 별칭으로 불러오기)

# %%
import matplotlib.pyplot as plt
plt.rc("font", family="Malgun Gothic")

# %%
#지역명으로 분양가격의 평균을 구하고 선그래프로 시각화하기
g = df_last.groupby(["지역명"])["평당분양가격"].mean().sort_values(ascending = False)
g.plot()
# Out:
# <AxesSubplot:xlabel='지역명'>

# %%
g.plot.bar(rot=0, figsize=(10,3))
# Out:
# <AxesSubplot:xlabel='지역명'>

# %%
#전용면적으로 분양가격의 평균을 구하고 막대그래프(bar)로 시각화 합니다.
df_last.groupby(["전용면적"])["평당분양가격"].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='전용면적'>

# %%
#연도별 분양가격의 평균을 구하고 막대 그래프로 시각화
df_last.groupby(["연도"])["평당분양가격"].mean().plot()
# Out:
# <AxesSubplot:xlabel='연도'>

# %% [markdown]
# #박스 플롯으로 시각화 하기
# 1. 최솟값
# 2. 제 1사분위수
# 3. 제 2사분위수(), 즉 중앙값
# 4. 제 3사분위 수()
# 5. 최댓값

# %%
df_last.pivot_table(index="월",columns="연도",values="평당분양가격").plot.box()
# Out:
# <AxesSubplot:>

# %%
p = df_last.pivot_table(index="월",columns=["연도","전용면적"],values="평당분양가격")
p.plot.box(figsize=(15,3), rot=3)
# Out:
# <AxesSubplot:>

# %%
p = df_last.pivot_table(index="연도",columns="월",values="평당분양가격")
p.plot(figsize=(10,10),rot=30)
# Out:
# <AxesSubplot:xlabel='연도'>

# %% [markdown]
# Seaborn으로 시각화 해보기

# %%
import seaborn as sns
# %matplotlib inline

# %%
#barplot으로 지역별 평당분양가격을 그려봅니다.
#연산을 하지 않아도 seaborn 내부자체에서 제공
plt.figure(figsize=(10,3))
sns.barplot(data=df_last, x="지역명", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
#barplot으로 연도별 평당분양가격을 그려봅니다.
sns.barplot(data=df_last, x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
sns.catplot(data=df_last, x="연도", y="평당분양가격",kind="bar", col="지역명", col_wrap=4)

# %%
#seaborn은 사용법이 비슷하다
plt.figure(figsize=(10,5))
sns.lineplot(data=df_last, x="연도", y="평당분양가격", hue="지역명")

#레전드값을 바깥에 그릴수 있게 하는 방법
plt.legend(bbox_to_anchor=(1.02,1), loc=2, borderaxespad=0.)

# %%
sns.relplot(data=df_last, x="연도", y="평당분양가격", 
            hue="지역명",kind="line", ci=None)

# %% [markdown]
# boxplot과 violinplot 으로 그리기

# %%
#연도별 평당 분양가격을 boxplot으로 그려봅니다.
sns.boxplot(data=df_last, x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
#hue 욥션을 주어 전용면적별로 다르게 표시해 봅니다.
plt.figure(figsize=(12,3))
sns.boxplot(data=df_last, x="연도", y="평당분양가격",hue="전용면적")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
#연도별 평당분양가격을 violinplot으로 그려봅니다.
sns.violinplot(data=df_last, x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %% [markdown]
# ### Implot과 swarmplot

# %%
#연도별 평당분양가격을 lmplot으로 그려봅니다.
#hue옵션을 전용면적을 표현해 봅니다.
sns.scatterplot(data=df_last, x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
sns.lmplot(data=df_last, x="연도", y="평당분양가격", hue="전용면적",col="전용면적", col_wrap=3)

# %%
#연도별 평당분양각격을 swarmplot으로 그려봅니다.
#swarmplot은 범주형(카테고리)데이터의 산점도를 표현하기에 적합합니다.
#plt.figure(figsize=(15,3))
#sns.swarmplot(data=df_last, x="연도", y="평당분양가격",hue="전용면적")

# %%
#이상치 보기
#평당분양가격의 최대값을 구해서 max_price라는 변수에 담습니다
df_last["평당분양가격"].describe()
# Out:
# count     5548.000000
# mean     11385.060076
# std       4641.778765
# min       6164.400000
# 25%       8471.100000
# 50%      10111.200000
# 75%      12906.300000
# max      45655.500000
# Name: 평당분양가격, dtype: float64

# %%
max_price = df_last["평당분양가격"].max()
max_price
# Out:
# 45655.5

# %%
#서울의 평당분양가격이 특히 높은 데이터가 있습니다. 해당 데이터를 가져옵니다.
df_last[df_last["평당분양가격"]==max_price]
# Out:
#      지역명    연도  월     분양가격   평당분양가격            전용면적
# 4423  서울  2020  2  13835.0  45655.5  85제곱미터~102제곱미터
# 4508  서울  2020  3  13835.0  45655.5  85제곱미터~102제곱미터
# 4593  서울  2020  4  13835.0  45655.5  85제곱미터~102제곱미터

# %% [markdown]
# ###수치 데이터 히스토그램으로 그리기
#
# distplot은 결측치가 있으면 그래프를 그릴 때 오류가 납니다. 따라서 결측치가 아닌 데이터만 따로 모아서 평당분양가격을 시각화하기 위한 데이터를 만듭니다. 데이터프레임의 .loc를 활용하여 결측치가 없는 데이터에서 평당분양가격만 가져옵니다.

# %%
#결측치가 없는 데이터에서 평당분양가격만 가져옵니다. 그리고 price라는 변수에 담습니다.
#.loc[행]
#.loc[행,열]
h = df_last.hist(bins=10) #bins 몇개로 나누어 담을것인가

# %%
h = df_last["평당분양가격"].hist(bins=10) #bins 몇개로 나누어 담을것인가

# %%
#결측치가 없는 데이터에서 평당분양가격만 가져옵니다. 그리고 price라는 변수에 담습니다.
#.loc[행]
#.loc[행,열]
price = df_last.loc[df_last["평당분양가격"].notnull(), "평당분양가격"]

# %%
#distplot으로 평당분양가격을 표현해 봅니다.
#sns.distplot(price, hist=False, rug=True)
#sns.kdeplot(price,cumulative=True) #누적거래액 누적통화량할때
sns.kdeplot(price)
# Out:
# <AxesSubplot:xlabel='평당분양가격', ylabel='Density'>

# %% [markdown]
# distplot을 산마루 형태의 ridge plot으로 그릭
# #링크는 강의에서
# #subplot으로 표현해 봅니다.

# %%
#subplot으로 표현해 봅니다.
g = sns.FacetGrid(df_last, row="지역명",
                height=1.7, aspect=4,)
g.map(sns.distplot, "평당분양가격", hist=False, rug=True);
# Out:
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#pairplot
df_last_notnull = df_last.loc[df_last["평당분양가격"].notnull(),
                          ["연도","월","평당분양가격","지역명","전용면적"]]
sns.pairplot(df_last_notnull, hue="지역명")

# %%
#규모구분(전용면적)별로 value_counts를 사용해서 데이터를 집계해 봅시다.
df_last["전용면적"].value_counts()
# Out:
# 102제곱미터~          1207
# 60제곱미터            1207
# 85제곱미터~102제곱미터    1207
# 60제곱미터~85제곱미터     1207
# 모든면적              1207
# Name: 전용면적, dtype: int64

# %% [markdown]
# ##### 2015년 8월 이전 데이터 보기

# %%
#df_first 변수에 담겨있는 데이터프레임의 정보를 info를 통해 보기.

# %%
pd.options.display.max_columns =25

# %%
df_last.head()
# Out:
#   지역명    연도   월    분양가격   평당분양가격            전용면적
# 0  서울  2015  10  5841.0  19275.3            모든면적
# 1  서울  2015  10  5652.0  18651.6          60제곱미터
# 2  서울  2015  10  5882.0  19410.6   60제곱미터~85제곱미터
# 3  서울  2015  10  5721.0  18879.3  85제곱미터~102제곱미터
# 4  서울  2015  10  5879.0  19400.7        102제곱미터~

# %%
#df_first 변수에 담겨있는 데이터 프레임의 정보를 info를 통해 봅니다.
df_first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역        17 non-null     object
#  1   2013년12월  17 non-null     int64
#  2   2014년1월   17 non-null     int64
#  3   2014년2월   17 non-null     int64
#  4   2014년3월   17 non-null     int64
#  5   2014년4월   17 non-null     int64
#  6   2014년5월   17 non-null     int64
#  7   2014년6월   17 non-null     int64
#  8   2014년7월   17 non-null     int64
#  9   2014년8월   17 non-null     int64
#  10  2014년9월   17 non-null     int64
#  11  2014년10월  17 non-null     int64
#  12  2014년11월  17 non-null     int64
#  13  2014년12월  17 non-null     int64
#  14  2015년1월   17 non-null     int64
#  15  2015년2월   17 non-null     int64
#  16  2015년3월   17 non-null     int64
#  17  2015년4월   17 non-null     int64
#  18  2015년5월   17 non-null     int64
#  19  2015년6월   17 non-null     int64
# ...

# %%
#결측치가 있는 지 봅니다.
df_first.isnull().sum()
# Out:
# 지역          0
# 2013년12월    0
# 2014년1월     0
# 2014년2월     0
# 2014년3월     0
# 2014년4월     0
# 2014년5월     0
# 2014년6월     0
# 2014년7월     0
# 2014년8월     0
# 2014년9월     0
# 2014년10월    0
# 2014년11월    0
# 2014년12월    0
# 2015년1월     0
# 2015년2월     0
# 2015년3월     0
# 2015년4월     0
# 2015년5월     0
# 2015년6월     0
# 2015년7월     0
# 2015년8월     0
# dtype: int64

# %% [markdown]
# ###두개의 다른 데이터 타입을 합쳐주기 위해 melt를 이용한다.

# %%
df_first.head(1)
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
#
#    2014년7월  2014년8월  2014년9월  2014년10월  2014년11월  2014년12월  2015년1월  2015년2월  \
# 0    18742    19274    19404     19759     20242     20269    20670    20670
#
#    2015년3월  2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    19415    18842    18367    18374    18152    18443

# %%
df_first_melt = df_first.melt(id_vars="지역",var_name="기간",value_name="평당가격")
df_first_melt.head()
# Out:
#    지역        기간   평당가격
# 0  서울  2013년12월  18189
# 1  부산  2013년12월   8111
# 2  대구  2013년12월   8080
# 3  인천  2013년12월  10204
# 4  광주  2013년12월   6098

# %%
 df_first_melt.columns = ["지역명","기간","평당분양가격"]
df_first_melt.head(1)
# Out:
#   지역명        기간  평당분양가격
# 0  서울  2013년12월   18189

# %% [markdown]
# #연도와 월을 함수와 pandas의 apply를 통해 분리해서 새로운 컬럼으로 만들기

# %%
df_last.head(1)
# Out:
#   지역명    연도   월    분양가격   평당분양가격  전용면적
# 0  서울  2015  10  5841.0  19275.3  모든면적

# %%
df_first_melt.head(1)
# Out:
#   지역명        기간  평당분양가격
# 0  서울  2013년12월   18189

# %%
date = "2013년12월"
date
# Out:
# '2013년12월'

# %%
date.split("년")

# %%
date.split("년")[0]
# Out:
# '2013'

# %%
date.split("년")[1]
# Out:
# '12월'

# %%
date.split("년")[-1].replace("월","")
# Out:
# '12'

# %%
#parse_year라는 함수를 만듭니다.
#연도만 반환하도록 하며, 반환하는 데이터는 int 타입이 되도록 합니다.

def parse_year(date):
    year = date.split("년")[0]
    year = int(year)
    return year

y = parse_year(date)
type(y)
print(type(y))
y
# Out:
# <class 'int'>
# 2013

# %%
parse_year(date)
# Out:
# 2013

# %%
def parse_month(date):
    month = date.split("년")[-1].replace("월","")
    month = int(month)
    return month
parse_year(date)
# Out:
# 2013

# %%
parse_month(date)
# Out:
# 12

# %%
#apply를 활용해 연도만 추출해서 새로운 컬럼에 담습니다.
df_first_melt["연도"] = df_first_melt["기간"].apply(parse_year)

# %%
df_first_melt["연도"]
# Out:
# 0      2013
# 1      2013
# 2      2013
# 3      2013
# 4      2013
#        ...
# 352    2015
# 353    2015
# 354    2015
# 355    2015
# 356    2015
# Name: 연도, Length: 357, dtype: int64

# %%
df_first_melt["월"] = df_first_melt["기간"].apply(parse_month)

# %%
df_first_melt.head(1)
# Out:
#   지역명        기간  평당분양가격    연도   월
# 0  서울  2013년12월   18189  2013  12

# %%
#df_last와 병합을 하기 위해서는 컬럼의 이름이 같아야 합니다.
#sample을 활용해서 데이터를 미리보기 합니다.
df_last.sample()
# Out:
#      지역명    연도   월  분양가격  평당분양가격            전용면적
# 2268  충남  2017  12   NaN     NaN  85제곱미터~102제곱미터

# %%
df_last.columns.to_list()
# Out:
# ['지역명', '연도', '월', '분양가격', '평당분양가격', '전용면적']

# %%
cols = ['지역명','연도','월','평당분양가격']
cols
# Out:
# ['지역명', '연도', '월', '평당분양가격']

# %%
#최근 데이터가 담긴 df_last에는 전용면적이 있습니다.
#이전 데이터에는 전용면적이 없기 때문에 "전체"만 사용하도록 합니다.
#loc를 사용해서 전체에 해당하는 면적만 copy로 복사해서 df_last_prepare변수에 담습니다.
df_last_prepare = df_last.loc[df_last["전용면적"]== "모든면적",cols].copy()
df_last_prepare.head(1)
# Out:
#   지역명    연도   월   평당분양가격
# 0  서울  2015  10  19275.3

# %%
#df_first_melt에서 공통된 컬럼만 가져온 뒤
#copy로 복사해서 df_first_prepare 변수에 담습니다.
df_first_prepare = df_first_melt[cols].copy()
df_first_prepare.head(1)
# Out:
#   지역명    연도   월  평당분양가격
# 0  서울  2013  12   18189

# %% [markdown]
# #두개를 합칠 준비가 되었다.
# #이제 concat으로 두개의 데이터 프레임을 합쳐주자

# %%
df = pd.concat([df_first_prepare, df_last_prepare])
df.shape
# Out:
# (1564, 4)

# %%
#제대로 합쳐졌는지 미리보기를 합니다.
df.tail()
# Out:
#      지역명    연도  월   평당분양가격
# 6010  전북  2021  8   8877.0
# 6015  전남  2021  8  10490.7
# 6020  경북  2021  8  10602.9
# 6025  경남  2021  8  10642.5
# 6030  제주  2021  8  27574.8

# %%
#연도별로 데이터가 몇개씩 잇는지 value_counts를 통해 세어봅니다
df["연도"].value_counts(sort=False)
# Out:
# 2013     17
# 2014    204
# 2015    187
# 2016    204
# 2017    204
# 2018    204
# 2019    204
# 2020    204
# 2021    136
# Name: 연도, dtype: int64

# %% [markdown]
# ##pivot_table 사용하기

# %%
###Reshaping and pivot tablese###
#Reshaping by pivot DateFrame objects
#연도를 인덱스로, 지역명을 컬럼으로 평당분양가격을 피봇테이블로 그려봅니다.
t = pd.pivot_table(df, index="연도", columns="지역명",values="평당분양가격").round()
t
# Out:
# 지역명       강원       경기       경남       경북       광주       대구       대전       부산  \
# 연도
# 2013  6230.0  10855.0   6473.0   6168.0   6098.0   8080.0   8321.0   8111.0
# 2014  6332.0  10509.0   6729.0   6536.0   7588.0   8286.0   8240.0   9180.0
# 2015  6831.0  10489.0   7646.0   7035.0   7956.0   8707.0   8105.0   9633.0
# 2016  7011.0  11220.0   7848.0   7361.0   8899.0  10310.0   8502.0  10430.0
# 2017  7171.0  11841.0   8164.0   7803.0   9471.0  11507.0   9056.0  11664.0
# 2018  7681.0  13186.0   9019.0   8505.0   9856.0  12076.0  10180.0  12998.0
# 2019  8142.0  14469.0   9871.0   8857.0  11823.0  13852.0  11778.0  13116.0
# 2020  9331.0  14383.0  10161.0   9545.0  12500.0  15145.0  11094.0  13248.0
# 2021  9680.0  14112.0  10326.0  10251.0  13891.0  15464.0  11698.0  14348.0
#
# 지역명        서울       세종       울산       인천      전남      전북       제주      충남  \
# 연도
# 2013  18189.0   7601.0   8090.0  10204.0  5678.0  6282.0   7674.0  6365.0
# ...

# %%
#위에서 그린 피봇테이블을 히트맵으로 표현해 봅니다.
plt.figure(figsize=(15,10))
sns.heatmap(t.T, cmap="Blues",annot=True,fmt=".0f")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='지역명'>

# %%
#transpose =T를 사용하면 행과 열을 바꿔 줄 수 있습니다

# %%
#Groupby로 그려봅니다. 인덱스에 ["연도","지역명"]을 넣고 그려봅니다.
g = df.groupby(["연도","지역명"])["평당분양가격"].mean().unstack().round()
g
# Out:
# 지역명       강원       경기       경남       경북       광주       대구       대전       부산  \
# 연도
# 2013  6230.0  10855.0   6473.0   6168.0   6098.0   8080.0   8321.0   8111.0
# 2014  6332.0  10509.0   6729.0   6536.0   7588.0   8286.0   8240.0   9180.0
# 2015  6831.0  10489.0   7646.0   7035.0   7956.0   8707.0   8105.0   9633.0
# 2016  7011.0  11220.0   7848.0   7361.0   8899.0  10310.0   8502.0  10430.0
# 2017  7171.0  11841.0   8164.0   7803.0   9471.0  11507.0   9056.0  11664.0
# 2018  7681.0  13186.0   9019.0   8505.0   9856.0  12076.0  10180.0  12998.0
# 2019  8142.0  14469.0   9871.0   8857.0  11823.0  13852.0  11778.0  13116.0
# 2020  9331.0  14383.0  10161.0   9545.0  12500.0  15145.0  11094.0  13248.0
# 2021  9680.0  14112.0  10326.0  10251.0  13891.0  15464.0  11698.0  14348.0
#
# 지역명        서울       세종       울산       인천      전남      전북       제주      충남  \
# 연도
# 2013  18189.0   7601.0   8090.0  10204.0  5678.0  6282.0   7674.0  6365.0
# ...

# %%
#바뀐 행과 열을 히트맵으로 표현해 봅니다.
plt.figure(figsize=(15,7))
sns.heatmap(g.T, annot=True, fmt=".0f", cmap="Greens") #annot = True 숫자를 표시해준다.
# Out:
# <AxesSubplot:xlabel='연도', ylabel='지역명'>

# %% [markdown]
# ###2013년부터 최근 데이터까지 시각화하기
# ##연도별 평당분양가격 보기

# %%
#barplot으로 연도별 평당분양가격 그리기
sns.barplot(data=df, x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
#pointplot으로 연도별 평당분양가격 그리기
#pointplot으로 연도별 평당분양가격 그리고 지역별로 표현해 보기

plt.figure(figsize=(12,4))
sns.pointplot(data=df, x="연도",y="평당분양가격", hue="지역명") #기울기에 따라 값의 변화를 보기 좋다
plt.legend(bbox_to_anchor=(1.02,1), loc=2, borderaxespad=0.)

# %%
#서울만 barplot으로 그리기
df_seoul = df[df["지역명"]=="서울"].copy()
print(df_seoul.shape)

bp = sns.barplot(data=df_seoul, x="연도", y="평당분양가격",color="b")
bp
sp = sns.pointplot(data=df_seoul, x="연도", y="평당분양가격")
sp
# Out:
# (92, 4)
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
#연도별 평당분양각겨 boxplot그리기
sns.boxplot(data=df , x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
sns.boxenplot(data=df , x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
#연도별 평당분양가격 violinplot그리기
plt.figure(figsize=(10,5))
sns.violinplot(data=df , x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
sns.scatterplot(data=df , x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
#연도별 평당분양가격 swarmplot그리기
plt.figure(figsize=(12,5))
sns.swarmplot(data=df , x="연도", y="평당분양가격",hue="지역명")
plt.legend(bbox_to_anchor=(1.02,1), loc=2, borderaxespad=0.) 
#scatterplot보다 보기 편하다 swarmplot은.
# Out:
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 43.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 47.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 44.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plt.figure(figsize=(12,5))
sns.violinplot(data=df , x="연도", y="평당분양가격")
sns.swarmplot(data=df , x="연도", y="평당분양가격", hue="지역명")
plt.legend(bbox_to_anchor=(1.02,1), loc=2, borderaxespad=0.)
# Out:
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 49.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 54.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 48.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ##지역별 평당분양가격 보기

# %%
#barplot으로 지역별 평당분양가격 그리기
plt.figure(figsize=(12,5))
sns.barplot(data=df, x="지역명", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
#boxplot으로 지역별 평당분양가격 그리기
plt.figure(figsize=(12,5))
sns.boxplot(data=df, x="지역명", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
plt.figure(figsize=(12,5))
sns.boxenplot(data=df, x="지역명", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
#violinplot으로 지역별 평당분양가격 그리기
plt.figure(figsize=(25,5))
sns.violinplot(data=df, x="지역명", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
#swarmplot으로 지역별 평당분양가격 그리기
plt.figure(figsize=(12,5))
sns.swarmplot(data=df, x="지역명", y="평당분양가격", hue="연도")
# Out:
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 17.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 45.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 34.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 44.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ###데이터를 시각화는 어럽지 않으나, 데이터를 전처리하는 과정이 어렵고 , 전처리 하는것이 실력이라고 생각한다.
