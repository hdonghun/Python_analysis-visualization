# %%
import pandas as pd
import numpy as np

# %%
data = f'小红书博主分析.xlsx'

# %%
df = pd.read_excel('小红书博主分析.xlsx', engine = 'openpyxl', header = 2) #header = 2가 중요!

# %%
df
# Out:
#       序号   平台                                                 ID        粉丝  \
# 0      1  小红书                                               甜崽小睿      1.1w
# 1      2  小红书                                               小乔栗子      3.5w
# 2      3  小红书                                          Yuqkoq77       1.3w
# 3      4  小红书                                                波伏瓦       391
# 4      5  小红书                                                瘦三斤         1
# ..   ...  ...                                                ...       ...
# 183  225  小红书  🐻：小熊可可https://www.xiaohongshu.com/user/profile...   183/840
# 184  231  小红书  西棠超田https://www.xiaohongshu.com/user/profile/6...  209/1604
# 185  233  小红书  噗噗崽https://www.xiaohongshu.com/user/profile/61...   2905/2w
# 186  235  小红书  春杪https://www.xiaohongshu.com/user/profile/5be...  258/4861
# 187  236  小红书  花枝鼠鼠https://www.xiaohongshu.com/user/profile/5...   258/411
#
# ...

# %%
#df.drop(['Unnamed: 9'], axis =1 , inplace = True)

# %%
#df.drop(df.columns[9:], axis=1 , inplace=True)
#df

# %%
#df.rename(columns={'Unnamed: 1':'平台'}, inplace = True )
df
# Out:
#       序号   平台                                                 ID        粉丝  \
# 0      1  小红书                                               甜崽小睿      1.1w
# 1      2  小红书                                               小乔栗子      3.5w
# 2      3  小红书                                          Yuqkoq77       1.3w
# 3      4  小红书                                                波伏瓦       391
# 4      5  小红书                                                瘦三斤         1
# ..   ...  ...                                                ...       ...
# 183  225  小红书  🐻：小熊可可https://www.xiaohongshu.com/user/profile...   183/840
# 184  231  小红书  西棠超田https://www.xiaohongshu.com/user/profile/6...  209/1604
# 185  233  小红书  噗噗崽https://www.xiaohongshu.com/user/profile/61...   2905/2w
# 186  235  小红书  春杪https://www.xiaohongshu.com/user/profile/5be...  258/4861
# 187  236  小红书  花枝鼠鼠https://www.xiaohongshu.com/user/profile/5...   258/411
#
# ...

# %%
df.fillna(0)
# Out:
#       序号   平台                                                 ID        粉丝  \
# 0      1  小红书                                               甜崽小睿      1.1w
# 1      2  小红书                                               小乔栗子      3.5w
# 2      3  小红书                                          Yuqkoq77       1.3w
# 3      4  小红书                                                波伏瓦       391
# 4      5  小红书                                                瘦三斤         1
# ..   ...  ...                                                ...       ...
# 183  225  小红书  🐻：小熊可可https://www.xiaohongshu.com/user/profile...   183/840
# 184  231  小红书  西棠超田https://www.xiaohongshu.com/user/profile/6...  209/1604
# 185  233  小红书  噗噗崽https://www.xiaohongshu.com/user/profile/61...   2905/2w
# 186  235  小红书  春杪https://www.xiaohongshu.com/user/profile/5be...  258/4861
# 187  236  小红书  花枝鼠鼠https://www.xiaohongshu.com/user/profile/5...   258/411
#
# ...
