# %%
import sklearn

print(sklearn.__version__)
# Out:
# 1.0.2

# %%
import xgboost

print(xgboost.__version__)
# Out:
# 1.5.0

# %%
import pandas as pd
import numpy as np
import openpyxl
import seaborn as sns

# 모든 데이터를 볼 수 있는 ( head랑 tail만 보여주는게 아니라, 다 보여주는 방법)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# .plot(kind = 'bar', rot=0)
# rot는 X축 라벨의 회전(rotation) 각도를 설정하는 데 사용한다.

# %%
# 데이터 받아 오기
data_name = f"NEW(1).csv"

# %%
data_name
# Out:
# 'NEW(1).csv'

# %%
data_name = pd.read_csv(data_name) #Encoding cp949는 못함,

# %%
df = data_name
df
# Out:
#       序号      平台              ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片  \
# 0      1     小红书            甜崽小睿  11000       NaN  100  NaN  1.0     2
# 1      2     小红书            小乔栗子  35000       NaN  100  1.0  NaN     2
# 2      3     小红书       Yuqkoq77   13000       NaN  100  NaN  1.0     2
# 3      4     小红书             波伏瓦    391       NaN  100  NaN  1.0     1
# 4      5     小红书             瘦三斤      1       NaN  100  NaN  1.0     1
# 5      6     小红书       UKNO0000Y     21       NaN  100  NaN  1.0     1
# 6      7     小红书             大橙纸    252       NaN  100  NaN  1.0     1
# 7      8     小红书          明天不熬夜了    248       NaN  100  NaN  1.0     1
# 8      9     小红书          聪明的小刘刘    398       NaN  100  NaN  1.0     1
# 9     10  小红书/抖音           猪场老板   12000       NaN  100  1.0  NaN     2
# 10    11     小红书           苗苗布丁冻  12000       NaN  100  NaN  1.0     2
# 11    12     小红书             燃燃_    723       NaN  100  NaN  1.0     1
# ...

# %%
df
# Out:
#       序号      平台              ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片  \
# 0      1     小红书            甜崽小睿  11000       NaN  100  NaN  1.0     2
# 1      2     小红书            小乔栗子  35000       NaN  100  1.0  NaN     2
# 2      3     小红书       Yuqkoq77   13000       NaN  100  NaN  1.0     2
# 3      4     小红书             波伏瓦    391       NaN  100  NaN  1.0     1
# 4      5     小红书             瘦三斤      1       NaN  100  NaN  1.0     1
# 5      6     小红书       UKNO0000Y     21       NaN  100  NaN  1.0     1
# 6      7     小红书             大橙纸    252       NaN  100  NaN  1.0     1
# 7      8     小红书          明天不熬夜了    248       NaN  100  NaN  1.0     1
# 8      9     小红书          聪明的小刘刘    398       NaN  100  NaN  1.0     1
# 9     10  小红书/抖音           猪场老板   12000       NaN  100  1.0  NaN     2
# 10    11     小红书           苗苗布丁冻  12000       NaN  100  NaN  1.0     2
# 11    12     小红书             燃燃_    723       NaN  100  NaN  1.0     1
# ...

# %%
df.head(5)
# Out:
#    序号   平台         ID    粉丝数  赞藏总数   价钱   视频   图文  眼膜/片  \
# 0   1  小红书       甜崽小睿  11000   NaN  100  NaN  1.0     2
# 1   2  小红书       小乔栗子  35000   NaN  100  1.0  NaN     2
# 2   3  小红书  Yuqkoq77   13000   NaN  100  NaN  1.0     2
# 3   4  小红书        波伏瓦    391   NaN  100  NaN  1.0     1
# 4   5  小红书        瘦三斤      1   NaN  100  NaN  1.0     1
#
#                                                 图文链接  Unnamed: 10 Unnamed: 11  \
# 0  https://000000000000.xiaohongshu.com/discovery...          NaN         NaN
# 1  https://000000000000.xiaohongshu.com/discovery...          NaN         NaN
# 2  https://000000000000.xiaohongshu.com/discovery...          NaN         NaN
# 3  https://000000000000.xiaohongshu.com/discovery...          NaN         NaN
# 4  https://000000000000.xiaohongshu.com/discovery...          NaN         NaN
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
#df = df.drop(["Unnamed: 9"], axis=1)
df = df.drop(["Unnamed: 10"], axis=1)
df = df.drop(["Unnamed: 11"], axis=1)
df = df.drop(["Unnamed: 12"], axis=1)
df = df.drop(["Unnamed: 13"], axis=1)
df = df.drop(["Unnamed: 14"], axis=1)
df = df.drop(["Unnamed: 15"], axis=1)
df = df.drop(["Unnamed: 16"], axis=1)
df = df.drop(["Unnamed: 17"], axis=1)

# %%
df
# Out:
#       序号      平台              ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片  \
# 0      1     小红书            甜崽小睿  11000       NaN  100  NaN  1.0     2
# 1      2     小红书            小乔栗子  35000       NaN  100  1.0  NaN     2
# 2      3     小红书       Yuqkoq77   13000       NaN  100  NaN  1.0     2
# 3      4     小红书             波伏瓦    391       NaN  100  NaN  1.0     1
# 4      5     小红书             瘦三斤      1       NaN  100  NaN  1.0     1
# 5      6     小红书       UKNO0000Y     21       NaN  100  NaN  1.0     1
# 6      7     小红书             大橙纸    252       NaN  100  NaN  1.0     1
# 7      8     小红书          明天不熬夜了    248       NaN  100  NaN  1.0     1
# 8      9     小红书          聪明的小刘刘    398       NaN  100  NaN  1.0     1
# 9     10  小红书/抖音           猪场老板   12000       NaN  100  1.0  NaN     2
# 10    11     小红书           苗苗布丁冻  12000       NaN  100  NaN  1.0     2
# 11    12     小红书             燃燃_    723       NaN  100  NaN  1.0     1
# ...

# %%
# 데이터 평균치 등등 나타내기
df.describe()
# Out:
#                序号           粉丝数           赞藏总数          价钱         视频     图文  \
# count  186.000000    186.000000     131.000000  186.000000  10.000000  177.0
# mean   108.118280   7554.075269   37213.992366   58.010753   0.900000    1.0
# std     64.304991  12930.511388   95431.803672   80.463656   0.316228    0.0
# min      1.000000      1.000000     127.000000    0.000000   0.000000    1.0
# 25%     54.250000    226.500000    1553.500000    0.000000   1.000000    1.0
# 50%    107.000000    609.500000    4861.000000    0.000000   1.000000    1.0
# 75%    158.750000  12000.000000   22000.000000  100.000000   1.000000    1.0
# max    236.000000  80000.000000  750000.000000  330.000000   1.000000    1.0
#
#              眼膜/片
# count  186.000000
# mean     1.698925
# std      0.802495
# min      1.000000
# 25%      1.000000
# 50%      2.000000
# 75%      2.000000
# max      7.000000

# %%
df.shape
# Out:
# (186, 10)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=186, step=1)

# %%
df.columns
# Out:
# Index(['序号', '平台', 'ID', '粉丝数', '赞藏总数', '价钱', '视频', '图文', '眼膜/片', '图文链接'], dtype='object')

# %%
# 모든 데이터를 볼 수 있는 ( head랑 tail만 보여주는게 아니라, 다 보여주는 방법)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#       序号      平台              ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片  \
# 0      1     小红书            甜崽小睿  11000       NaN  100  NaN  1.0     2
# 1      2     小红书            小乔栗子  35000       NaN  100  1.0  NaN     2
# 2      3     小红书       Yuqkoq77   13000       NaN  100  NaN  1.0     2
# 3      4     小红书             波伏瓦    391       NaN  100  NaN  1.0     1
# 4      5     小红书             瘦三斤      1       NaN  100  NaN  1.0     1
# 5      6     小红书       UKNO0000Y     21       NaN  100  NaN  1.0     1
# 6      7     小红书             大橙纸    252       NaN  100  NaN  1.0     1
# 7      8     小红书          明天不熬夜了    248       NaN  100  NaN  1.0     1
# 8      9     小红书          聪明的小刘刘    398       NaN  100  NaN  1.0     1
# 9     10  小红书/抖音           猪场老板   12000       NaN  100  1.0  NaN     2
# 10    11     小红书           苗苗布丁冻  12000       NaN  100  NaN  1.0     2
# 11    12     小红书             燃燃_    723       NaN  100  NaN  1.0     1
# ...

# %%
df.iloc[0:4] # 인덱스 기준 4개
# Out:
#    序号   平台         ID    粉丝数  赞藏总数   价钱   视频   图文  眼膜/片  \
# 0   1  小红书       甜崽小睿  11000   NaN  100  NaN  1.0     2
# 1   2  小红书       小乔栗子  35000   NaN  100  1.0  NaN     2
# 2   3  小红书  Yuqkoq77   13000   NaN  100  NaN  1.0     2
# 3   4  小红书        波伏瓦    391   NaN  100  NaN  1.0     1
#
#                                                 图文链接
# 0  https://000000000000.xiaohongshu.com/discovery...
# 1  https://000000000000.xiaohongshu.com/discovery...
# 2  https://000000000000.xiaohongshu.com/discovery...
# 3  https://000000000000.xiaohongshu.com/discovery...

# %%
df.loc[0:4] # 0:4 사이의 5개 개수를 첫번 쨰 인덱스부터 추출
# Out:
#    序号   平台         ID    粉丝数  赞藏总数   价钱   视频   图文  眼膜/片  \
# 0   1  小红书       甜崽小睿  11000   NaN  100  NaN  1.0     2
# 1   2  小红书       小乔栗子  35000   NaN  100  1.0  NaN     2
# 2   3  小红书  Yuqkoq77   13000   NaN  100  NaN  1.0     2
# 3   4  小红书        波伏瓦    391   NaN  100  NaN  1.0     1
# 4   5  小红书        瘦三斤      1   NaN  100  NaN  1.0     1
#
#                                                 图文链接
# 0  https://000000000000.xiaohongshu.com/discovery...
# 1  https://000000000000.xiaohongshu.com/discovery...
# 2  https://000000000000.xiaohongshu.com/discovery...
# 3  https://000000000000.xiaohongshu.com/discovery...
# 4  https://000000000000.xiaohongshu.com/discovery...

# %%
#데이터 전처리 과정
new_df = df.loc[:,['序号','平台','ID','粉丝数','赞藏总数','价钱','视频','图文','眼膜/片']]

# %%
new_df
# Out:
#       序号      平台              ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片
# 0      1     小红书            甜崽小睿  11000       NaN  100  NaN  1.0     2
# 1      2     小红书            小乔栗子  35000       NaN  100  1.0  NaN     2
# 2      3     小红书       Yuqkoq77   13000       NaN  100  NaN  1.0     2
# 3      4     小红书             波伏瓦    391       NaN  100  NaN  1.0     1
# 4      5     小红书             瘦三斤      1       NaN  100  NaN  1.0     1
# 5      6     小红书       UKNO0000Y     21       NaN  100  NaN  1.0     1
# 6      7     小红书             大橙纸    252       NaN  100  NaN  1.0     1
# 7      8     小红书          明天不熬夜了    248       NaN  100  NaN  1.0     1
# 8      9     小红书          聪明的小刘刘    398       NaN  100  NaN  1.0     1
# 9     10  小红书/抖音           猪场老板   12000       NaN  100  1.0  NaN     2
# 10    11     小红书           苗苗布丁冻  12000       NaN  100  NaN  1.0     2
# 11    12     小红书             燃燃_    723       NaN  100  NaN  1.0     1
# ...

# %%
new_df = new_df.fillna(value=0)

# %%
new_df
# Out:
#       序号      平台              ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片
# 0      1     小红书            甜崽小睿  11000       0.0  100  0.0  1.0     2
# 1      2     小红书            小乔栗子  35000       0.0  100  1.0  0.0     2
# 2      3     小红书       Yuqkoq77   13000       0.0  100  0.0  1.0     2
# 3      4     小红书             波伏瓦    391       0.0  100  0.0  1.0     1
# 4      5     小红书             瘦三斤      1       0.0  100  0.0  1.0     1
# 5      6     小红书       UKNO0000Y     21       0.0  100  0.0  1.0     1
# 6      7     小红书             大橙纸    252       0.0  100  0.0  1.0     1
# 7      8     小红书          明天不熬夜了    248       0.0  100  0.0  1.0     1
# 8      9     小红书          聪明的小刘刘    398       0.0  100  0.0  1.0     1
# 9     10  小红书/抖音           猪场老板   12000       0.0  100  1.0  0.0     2
# 10    11     小红书           苗苗布丁冻  12000       0.0  100  0.0  1.0     2
# 11    12     小红书             燃燃_    723       0.0  100  0.0  1.0     1
# ...

# %%
df = new_df

# %% [markdown]
# ----------------------------3번 부분--------------------------

# %%
df.describe()
# Out:
#                序号           粉丝数           赞藏总数          价钱          视频  \
# count  186.000000    186.000000     186.000000  186.000000  186.000000
# mean   108.118280   7554.075269   26209.854839   58.010753    0.048387
# std     64.304991  12930.511388   81790.283020   80.463656    0.215162
# min      1.000000      1.000000       0.000000    0.000000    0.000000
# 25%     54.250000    226.500000       0.000000    0.000000    0.000000
# 50%    107.000000    609.500000    1567.500000    0.000000    0.000000
# 75%    158.750000  12000.000000    9863.500000  100.000000    0.000000
# max    236.000000  80000.000000  750000.000000  330.000000    1.000000
#
#                图文        眼膜/片
# count  186.000000  186.000000
# mean     0.951613    1.698925
# std      0.215162    0.802495
# min      0.000000    1.000000
# 25%      1.000000    1.000000
# 50%      1.000000    2.000000
# 75%      1.000000    2.000000
# max      1.000000    7.000000

# %% [markdown]
# ### 여기서 부터 분석 시작

# %%
#df.plot.bar()
#import seaborn as sns
#import matplotlib.pyplot as plt
#plt.figure(figsize=(15,4))
#sns.barplot(data=df, x="平台", y = "粉丝")

# %%
## 중국어 폰트 설정 하는 방법

import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False
f_path = "C:\Windows\Fonts/simhei.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# 폰트를 선명하게 하기
# retina설정
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %%
# 컬럼 fan을 시리즈 형태로 바꾸어서 빈도수 구하기

#dfs_fan = pd.Series(df["粉丝数"]).value_counts()

# %%
#dfs_fan.head(50).plot.barh(figsize=(15,15))

# %% [markdown]
# -------------------------------1번 부분------------------

# %%
sns.countplot(data=df, x="平台") 
#我收到的数据里 博主用那个平台多少
#最多的是只有小红书
#所以如果要投资，最好集中看小红书
#내가 받은 데이터에는 인플러언서가 어떠한 플랫폼을 가장 많이 이용하는지
# Out:
# <AxesSubplot:xlabel='平台', ylabel='count'>

# %% [markdown]
# ----------------------------2번 부분----------------------------

# %%
df.groupby(["粉丝数","ID"])["平台"].mean
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.generic.SeriesGroupBy object at 0x0000022A6E189640>>

# %%
plt.figure(figsize=(12,35))
df_f_id_pingtai = sns.barplot(data=df, x="粉丝数", y ="ID", hue="平台") 
# 1.파란색 2.빨강색 순으로 平台에 粉丝数가 많다
# 在小红书 ，小红书和逛逛 平台的顺序 有了多的粉丝数，所以这个两个方面投资看起来很有期待价值。
# Out:
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#plt.figure(figsize=(15,15))
#df_fensishu = df["赞藏总数"].sort_values()
#df_fensishu.plot.barh()

# %%
df
# Out:
#       序号      平台              ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片
# 0      1     小红书            甜崽小睿  11000       0.0  100  0.0  1.0     2
# 1      2     小红书            小乔栗子  35000       0.0  100  1.0  0.0     2
# 2      3     小红书       Yuqkoq77   13000       0.0  100  0.0  1.0     2
# 3      4     小红书             波伏瓦    391       0.0  100  0.0  1.0     1
# 4      5     小红书             瘦三斤      1       0.0  100  0.0  1.0     1
# 5      6     小红书       UKNO0000Y     21       0.0  100  0.0  1.0     1
# 6      7     小红书             大橙纸    252       0.0  100  0.0  1.0     1
# 7      8     小红书          明天不熬夜了    248       0.0  100  0.0  1.0     1
# 8      9     小红书          聪明的小刘刘    398       0.0  100  0.0  1.0     1
# 9     10  小红书/抖音           猪场老板   12000       0.0  100  1.0  0.0     2
# 10    11     小红书           苗苗布丁冻  12000       0.0  100  0.0  1.0     2
# 11    12     小红书             燃燃_    723       0.0  100  0.0  1.0     1
# ...

# %% [markdown]
# ----------------팬수가 가장 많은 博主-----------------

# %%
# “粉丝数”가 2000명 이상인것만 가져오기
df_粉丝数 = df[df["粉丝数"]>20000].sort_values(by="粉丝数",ascending=False)
plt.figure(figsize=(10,10))
sns.barplot(data=df_粉丝数, x="粉丝数", y="ID",ci=None)
# Out:
# <AxesSubplot:xlabel='粉丝数', ylabel='ID'>
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# --------------------------赞藏总数 博主 4000이상-------------------------

# %%
df_like = df[df["赞藏总数"] > 30000].sort_values(by="赞藏总数" , ascending = False)

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=df_like, x="赞藏总数", y="ID",ci=None)
# Out:
# <AxesSubplot:xlabel='赞藏总数', ylabel='ID'>

# %% [markdown]
# ------------------------------------价钱 博主------------------------------------

# %%
# 0원 인것은 제외
df_money = df[df["价钱"] > 100].sort_values(by="价钱" , ascending = False)

# %%
plt.figure(figsize=(10,15))
sns.barplot(data=df_money, x="价钱", y = "ID")
# Out:
# <AxesSubplot:xlabel='价钱', ylabel='ID'>
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# （4）가격,팬수,좋아요를 비교했을 때 이상한 데이터 부분--------

# %%
# df_like = 赞藏总数 가 100000이상 으로 설정 + 크기순으로 정렬하기
df_like = df[df["赞藏总数"] > 100000].sort_values(by="赞藏总数" , ascending = False)
df_like.head()
# Out:
#     序号      平台          ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片
# 73  83     小红书        满杯芝士  58000  750000.0  300  0.0  1.0     2
# 80  93     小红书       狂恋美杜莎  65000  503000.0  300  0.0  1.0     2
# 60  69     小红书  mojingying  10000  386000.0  200  0.0  1.0     1
# 79  92     小红书       茵茵长不高  37000  320000.0  180  0.0  1.0     1
# 53  61  小红书/微博        脑浆冻冻  11000  250000.0  150  0.0  1.0     1

# %%
plt.figure(figsize=(7,7))
sns.barplot(data=df_like, x="赞藏总数", y = "ID", hue="价钱",linewidth=50,palette = 'colorblind')
# Out:
# <AxesSubplot:xlabel='赞藏总数', ylabel='ID'>

# %%
# “粉丝数”가 1000명 이상인것만 가져오기
df_粉丝数.head()
# Out:
#     序号      平台      ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片
# 20  24  小红书/逛逛   等等马上好  80000       0.0  300  0.0  1.0     2
# 80  93     小红书   狂恋美杜莎  65000  503000.0  300  0.0  1.0     2
# 75  85     小红书  吃草莓的吨吨  62000  135000.0  300  1.0  0.0     2
# 73  83     小红书    满杯芝士  58000  750000.0  300  0.0  1.0     2
# 19  23  小红书/逛逛   爱吃皮蛋林  49000       0.0  200  0.0  1.0     1

# %%
# “粉丝数”가 2000명 이상인것만 가져오기
df_粉丝数 = df[df["粉丝数"]>30000].sort_values(by="粉丝数",ascending=False)
plt.figure(figsize=(7,7))
sns.barplot(data=df_粉丝数, x="粉丝数", y = "ID", hue="价钱", linewidth=100, palette = 'colorblind')
# Out:
# <AxesSubplot:xlabel='粉丝数', ylabel='ID'>
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df[(df["视频"] ==1) & (df["价钱"]!=0)].sort_values(by="价钱", ascending = False)
# 博主的ID“吃草莓的吨吨”的粉丝数和赞藏总数比ID“你的金桔”更高，还有视频和图文和眼膜/片一样
# 但是ID“你的金桔”的价钱更高30块钱
# 倒是ID“你的金桔”跟ID“小乔栗子”粉丝数差不多，赞藏总数，价钱，视频，图文，眼膜/片 一样。但是这两个博主的价钱差异230块钱
#df_money = df[df["价钱"]].sort_values(by="价钱", ascending = False)
# Out:
#     序号      平台        ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片
# 34  40  小红书/逛逛  你的金桔      38000       0.0  330  1.0  0.0     2
# 75  85     小红书    吃草莓的吨吨  62000  135000.0  300  1.0  0.0     2
# 1    2     小红书      小乔栗子  35000       0.0  100  1.0  0.0     2
# 9   10  小红书/抖音     猪场老板   12000       0.0  100  1.0  0.0     2

# %% [markdown]
# -----------------（5번) 가격,팬,좋아요를 비교했을때 가장 효과적인 사람 --------------------

# %%
df_new= df[df["赞藏总数"] > 9999].sort_values(by="赞藏总数",ascending = False)

# %%
df_new = df[df["粉丝数"] != 0].sort_values(by="粉丝数",ascending = False)

# %%
df_new
# Out:
#       序号      平台              ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片
# 20    24  小红书/逛逛           等等马上好  80000       0.0  300  0.0  1.0     2
# 80    93     小红书           狂恋美杜莎  65000  503000.0  300  0.0  1.0     2
# 75    85     小红书          吃草莓的吨吨  62000  135000.0  300  1.0  0.0     2
# 73    83     小红书            满杯芝士  58000  750000.0  300  0.0  1.0     2
# 19    23  小红书/逛逛           爱吃皮蛋林  49000       0.0  200  0.0  1.0     1
# 36    43     小红书             小予儿  43000       0.0  260  0.0  1.0     1
# 34    40  小红书/逛逛        你的金桔      38000       0.0  330  1.0  0.0     2
# 79    92     小红书           茵茵长不高  37000  320000.0  180  0.0  1.0     1
# 1      2     小红书            小乔栗子  35000       0.0  100  1.0  0.0     2
# 16    19  小红书/得物            九久阿米  34000       0.0  200  0.0  1.0     1
# 50    58     小红书           蜜桃苏打水  31000       0.0  200  0.0  1.0     1
# 38    45  小红书/逛逛       fmjfmjfmj  28000       0.0  150  0.0  1.0     1
# ...

# %% [markdown]
# df["粉丝数"]/df["赞藏总数"] 이렇게 만들어서 팬의 수 대비 좋아요 >> 누가 가장 효율적인지 누가지 변수로 분석

# %%
TT = df["粉丝数"]/df["赞藏总数"]
TT
# Out:
# 0           inf
# 1           inf
# 2           inf
# 3           inf
# 4           inf
# 5           inf
# 6           inf
# 7           inf
# 8           inf
# 9           inf
# 10          inf
# 11          inf
# 12          inf
# 13          inf
# 14          inf
# 15          inf
# 16          inf
# 17          inf
# 18          inf
# 19          inf
# 20          inf
# 21          inf
# 22          inf
# 23          inf
# 24          inf
# 25          inf
# 26          inf
# 27          inf
# 28          inf
# 29          inf
# 30          inf
# 31          inf
# 32          inf
# 33          inf
# 34          inf
# 35          inf
# 36          inf
# 37          inf
# 38          inf
# 39          inf
# 40          inf
# 41          inf
# 42          inf
# 43          inf
# 44          inf
# 45          inf
# 46          inf
# 47          inf
# 48          inf
# 49          inf
# 50          inf
# 51          inf
# 52          inf
# 53     0.044000
# 54     0.120000
# ...

# %%
有效投放 = f"950223.csv" #"粉丝数/赞藏" 이렇게 분석한 엑셀 파일 받아오기
有效投放 = pd.read_csv(有效投放)

# %%
有效投放
# Out:
#       序号    粉丝数/赞藏
# 0     80  0.129225
# 1     75  0.459259
# 2     73  0.077333
# 3     79  0.115625
# 4     56  0.237288
# 5     66  0.139073
# 6     69  0.321429
# 7     62  0.113924
# 8     71  0.310345
# 9     65  0.121429
# 10    64  0.265625
# 11    63  0.326531
# 12    57  0.176471
# 13    54  0.120000
# 14    61  0.157895
# 15    67  0.179487
# 16    74  0.194030
# 17    68  0.500000
# 18    53  0.044000
# 19    70  0.186441
# 20   152  0.220000
# 21    59  0.224490
# 22    81  0.250000
# 23    55  0.343750
# 24   154  0.116279
# 25    60  0.025907
# 26   113  1.738175
# 27   155  0.200500
# 28   178  0.810912
# 29   169  0.760066
# 30   168  0.719840
# 31   100  0.024456
# 32   148  1.515839
# 33    91  0.143958
# 34    98  0.150550
# 35   183  0.145250
# 36   140  0.253195
# 37    92  0.057063
# 38   180  0.086053
# 39   134  0.008313
# 40   151  0.270655
# 41    78  0.666451
# 42    89  0.146625
# 43    86  0.170016
# 44   163  0.145306
# 45    84  0.416347
# ...

# %%
有效投放 = 有效投放.sort_values(by="粉丝数/赞藏",ascending=False)
有效投放
# Out:
#       序号    粉丝数/赞藏
# 26   113  1.738175
# 32   148  1.515839
# 91   171  0.855372
# 28   178  0.810912
# 29   169  0.760066
# 70   127  0.726733
# 30   168  0.719840
# 88   105  0.684211
# 41    78  0.666451
# 83   185  0.627737
# 87    76  0.522678
# 17    68  0.500000
# 48   119  0.465843
# 1     75  0.459259
# 80   170  0.456140
# 46   120  0.442995
# 45    84  0.416347
# 111  160  0.368932
# 54   130  0.359565
# 23    55  0.343750
# 101  175  0.340136
# 11    63  0.326531
# 6     69  0.321429
# 8     71  0.310345
# 63   125  0.291933
# 62   146  0.290631
# 71    90  0.285714
# 78   123  0.285171
# 76    83  0.284588
# 58    85  0.279743
# 40   151  0.270655
# 10    64  0.265625
# 61   131  0.254489
# 36   140  0.253195
# 22    81  0.250000
# 68   145  0.248330
# 4     56  0.237288
# 64   158  0.229376
# 126  111  0.228346
# 21    59  0.224490
# 67    99  0.221087
# 20   152  0.220000
# 81   129  0.219360
# 92   181  0.217857
# 85   117  0.201575
# 27   155  0.200500
# ...

# %% [markdown]
# 113
# 148
# 171
# 178
# 169
# 127
# 168
# 105
# 78
# 185
# 76
# 68

# %%
plt.figure(figsize=(35,5))
sns.barplot(data = 有效投放, x="序号", y ="粉丝数/赞藏")
# Out:
# <AxesSubplot:xlabel='序号', ylabel='粉丝数/赞藏'>

# %% [markdown]
# ## Conclusion 结果

# %% [markdown]
# 0.
#
# 为了首次进行数据分析,需要原因和结果的数据。 但是据说,我收到的资料中只有相当于原因的数据,没有关于结果的数据。 只属于这些原因的数据只能显示目前Eternaleaf投资的形态。 即,无法知道KEVIN想要的有效投放,无效投放。
#
#
# 1.
#
# 收到的数据有很多不足之处 (ex) 博主的广告时间、广告多少时间、主要看的顾客年龄层、性别等有很多变数

# %% [markdown]
# 2. 数据分析
#
# （1）我收到的数据里 博主用那个平台多少 ：最多的是只有小红书，所以如果要投资，最好集中看小红书

# %%
sns.countplot(data=df, x="平台")
#내가 받은 데이터에는 인플러언서가 어떠한 플랫폼을 가장 많이 이용하는지
# Out:
# <AxesSubplot:xlabel='平台', ylabel='count'>

# %% [markdown]
# （2）现在eternaleaf 投资在小红书 ，小红书和逛逛最高
#     在小红书 ，小红书和逛逛 平台的顺序 有了多的粉丝数，所以这个两个方面投资看起来很有期待价值.

# %%
plt.figure(figsize=(12,35))
df_f_id_pingtai = sns.barplot(data=df, x="粉丝数", y ="ID", hue="平台") # 1.파란색 2.빨강색 순으로 平台에 粉丝数가 많다
# Out:
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.barplot(data=df_粉丝数, x="粉丝数", y ="ID", hue="平台") # 1.파란색 2.빨강색 순으로 平台에 粉丝数가 많다
# Out:
# <AxesSubplot:xlabel='粉丝数', ylabel='ID'>
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# （3）平均值
#      Eternal公司跟下面的数据的博主平均联系了(签约)
#
#      粉丝数：7554.075269
#      赞藏总数：26209.854839
#      视频：0.048387
#      图文：0.951613
#      眼膜/片：1.698925
#      价钱：58.010753（置换产品的话假设了 价钱是0（零))

# %%
df.describe()
# Out:
#                序号           粉丝数           赞藏总数          价钱          视频  \
# count  186.000000    186.000000     186.000000  186.000000  186.000000
# mean   108.118280   7554.075269   26209.854839   58.010753    0.048387
# std     64.304991  12930.511388   81790.283020   80.463656    0.215162
# min      1.000000      1.000000       0.000000    0.000000    0.000000
# 25%     54.250000    226.500000       0.000000    0.000000    0.000000
# 50%    107.000000    609.500000    1567.500000    0.000000    0.000000
# 75%    158.750000  12000.000000    9863.500000  100.000000    0.000000
# max    236.000000  80000.000000  750000.000000  330.000000    1.000000
#
#                图文        眼膜/片
# count  186.000000  186.000000
# mean     0.951613    1.698925
# std      0.215162    0.802495
# min      0.000000    1.000000
# 25%      1.000000    1.000000
# 50%      1.000000    2.000000
# 75%      1.000000    2.000000
# max      1.000000    7.000000

# %% [markdown]
# (4) 粉丝数，赞藏总数，价钱，视频，图文，眼膜/片：一起看这种类型有奇怪的部分
#
# ID：博主"等等马上好"的粉丝数最高，价钱也最高，但是没有赞藏总数。我没收到销售数量，想看"等等马上好"博主的销售数量。因为想看赞藏总数的影响销售数量。
#
#     博主的ID“吃草莓的吨吨”的粉丝数和赞藏总数比ID“你的金桔”更高，还有视频和图文和眼膜/片一样。但是ID“你的金桔”的价钱更高30块钱。我觉得这样的签约无效投放的。倒是ID“你的金桔”跟ID“小乔栗子”粉丝数差不多，赞藏总数，价钱，视频，图文，眼膜/片一样。但是这两个博主的价钱差异230块钱

# %%
# df_like = 赞藏总数 가 100000이상 으로 설정 + 크기순으로 정렬하기
df_like = df[df["赞藏总数"] > 100000].sort_values(by="赞藏总数" , ascending = False)
plt.figure(figsize=(7,7))
sns.barplot(data=df_like, x="赞藏总数", y = "ID", hue="价钱",linewidth=50,palette = 'colorblind')

# “粉丝数”가 2000명 이상인것만 가져오기
df_粉丝数 = df[df["粉丝数"]>30000].sort_values(by="粉丝数",ascending=False)
plt.figure(figsize=(7,7))
sns.barplot(data=df_粉丝数, x="粉丝数", y = "ID", hue="价钱", linewidth=100, palette = 'colorblind')

df[(df["视频"] ==1) & (df["价钱"]!=0)].sort_values(by="价钱", ascending = False)
# 博主的ID“吃草莓的吨吨”的粉丝数和赞藏总数比ID“你的金桔”更高，还有视频和图文和眼膜/片一样
# 但是ID“你的金桔”的价钱更高30块钱
# 倒是ID“你的金桔”跟ID“小乔栗子”粉丝数差不多，赞藏总数，价钱，视频，图文，眼膜/片 一样。但是这两个博主的价钱差异230块钱
#df_money = df[df["价钱"]].sort_values(by="价钱", ascending = False)
# Out:
#     序号      平台        ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片
# 34  40  小红书/逛逛  你的金桔      38000       0.0  330  1.0  0.0     2
# 75  85     小红书    吃草莓的吨吨  62000  135000.0  300  1.0  0.0     2
# 1    2     小红书      小乔栗子  35000       0.0  100  1.0  0.0     2
# 9   10  小红书/抖音     猪场老板   12000       0.0  100  1.0  0.0     2
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\toyou\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# （5）粉丝数，赞藏总数：一起看这种类型
#
# （没有销售数量的数据，所以“粉丝数/赞藏总数”最高的效率 12个人，假设"赞藏总数"是销售量的话）

# %%
df_有效投放 = f"有效投放.csv"
df_有效投放 = pd.read_csv(df_有效投放) 
df_有效投放 = df_有效投放.drop(["Unnamed: 9"], axis=1)
df_有效投放[:11]
# Out:
#         序号   平台        ID      粉丝数     赞藏总数       价钱     视频   图文  眼膜/片
# 0    113.0  小红书       小团子   3011.0  20000.0      0.0    0.0  1.0   2.0
# 1    148.0  小红书     大头不秃头    281.0   1281.0      0.0    0.0  1.0   2.0
# 2    171.0  小红书      黄金矿工   3541.0   2336.0      0.0    0.0  1.0   2.0
# 3    178.0  小红书    一个洛洛人儿   1235.0   4563.0      0.0    0.0  1.0   2.0
# 4    169.0  小红书        南音    456.0   1569.0      0.0    0.0  1.0   2.0
# 5    127.0  小红书      玥玥ok     29.0    127.0      0.0    0.0  1.0   2.0
# 6    168.0  小红书   羊咩咩的杂货铺    409.0   1647.0      0.0    0.0  1.0   2.0
# 7    105.0  小红书       猪猪侠   3455.0  24000.0      0.0    0.0  1.0   2.0
# 8     78.0  小红书     来只烤兔$  18000.0  56000.0    100.0    0.0  1.0   1.0
# 9    185.0  小红书    绿子空气椅子      NaN    598.0  16000.0    0.0  0.0   1.0
# 10    76.0  小红书  Komorebi      NaN  14000.0  78000.0  120.0  0.0   1.0

# %%
plt.figure(figsize=(35,5))
sns.barplot(data = 有效投放, x="序号", y ="粉丝数/赞藏")
# Out:
# <AxesSubplot:xlabel='序号', ylabel='粉丝数/赞藏'>

# %% [markdown]
# --- 여기까지가 赞藏总数를 결과 값이라고 가정하고 분석을 한 내용들이고. ---

# %%
df.shape
# Out:
# (186, 9)

# %%
df.sort_values(by="序号",ascending=True)
# Out:
#       序号      平台              ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片
# 0      1     小红书            甜崽小睿  11000       0.0  100  0.0  1.0     2
# 1      2     小红书            小乔栗子  35000       0.0  100  1.0  0.0     2
# 2      3     小红书       Yuqkoq77   13000       0.0  100  0.0  1.0     2
# 3      4     小红书             波伏瓦    391       0.0  100  0.0  1.0     1
# 4      5     小红书             瘦三斤      1       0.0  100  0.0  1.0     1
# 5      6     小红书       UKNO0000Y     21       0.0  100  0.0  1.0     1
# 6      7     小红书             大橙纸    252       0.0  100  0.0  1.0     1
# 7      8     小红书          明天不熬夜了    248       0.0  100  0.0  1.0     1
# 8      9     小红书          聪明的小刘刘    398       0.0  100  0.0  1.0     1
# 9     10  小红书/抖音           猪场老板   12000       0.0  100  1.0  0.0     2
# 10    11     小红书           苗苗布丁冻  12000       0.0  100  0.0  1.0     2
# 11    12     小红书             燃燃_    723       0.0  100  0.0  1.0     1
# ...

# %% [markdown]
#  粉丝数대비 星星数，赞藏数，评论数 가 얼마나 되는지에 따라 상품의 관심도?를 나타내 보자
#
#  어떠한 지금 eternaleaf에서 在小红书 博主에 물건을 부탁하여 홍보를 하는 방식으로 제품을 판매하고 있는데,
#
#  지금 하는 방법이 효율적인지, 비효율ㅡ적인지 분석을 해야 됨. >> 하지만 지금 판매 수량, 즉 결과가 없다.
#
#  그럼에 따라 어떠한 방향으로 분석을 해야 효율과 비효율을 분석 할 수 있을 까 .........
#
#  원래는 赞藏总数가 결과라는 것으로 가정하여 분석하였는데, 지금 보니깐 즐겨찾기를 해놓으면 그 해당 상품에 즐겨찾기를 하는것이라.
#
#  즐겨찾기를 해당 결과라는 것으로 가졍하여 분석해보자...만약 시간이 있다면, 최종적으로 즐겨찾기와 좋아요를 더하여 이것을 새로운
#
#  변수로 놓아서 결과 값이라고 가정하고 분석을 해보자. >>> 여기까지가 지금 있는 데이터로 할 수 있는 최정적인 단계라고 생각한다.
#
#
#
#  博主한테 물건을 맡기고. 홍보를 부탁하는 과정에서 收费분석으로 효율적인지 확인 할 수 있을까?
#
#  이것이 최종적인거 :
#  (좋아요 / 팬), (즐겨찾기 / 팬), (좋아요+ 즐겨찾기 / 팬) 이 3가지 방법으로 제품에 대한 博主홍보영향도를 나타 낼 수 있다고 가정하자.
