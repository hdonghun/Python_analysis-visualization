# %%
import pandas as pd
import numpy as np
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# 모든 데이터를 볼 수 있는 ( head랑 tail만 보여주는게 아니라, 다 보여주는 방법)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
## 중국어 폰트 설정 하는 방법

import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False
f_path = "C:\Windows\Fonts/simhei.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# 폰트를 선명하게 하기
# retina설정
#from IPython.display import set_matplotlib_formats
#set_matplotlib_formats("retina")

# %% [markdown]
# # sheet 1

# %%
# 데이터 받아 오기
data_name = f"2.1~3.6 数据对比表.csv"
data_name = pd.read_csv(data_name) #Encoding cp949는 못함,

# %%
df = data_name
df
# Out:
#         日期  小程序（浏览量）  小程序（访客量）  淘宝（浏览量）  淘宝（访客量）  掌上大学  总阅读数（博主文章的预估阅读数）  \
# 0    02-21      16.0       4.0    184.0     23.0   0.0               NaN
# 1    02-22       7.0       2.0    114.0     30.0   0.0               NaN
# 2    02-23       8.0       1.0    155.0     18.0   0.0               NaN
# 3    02-24      22.0       3.0    119.0     19.0   0.0               NaN
# 4    02-25       3.0       1.0    102.0     31.0   0.0               NaN
# 5    02-26      13.0       4.0    127.0     28.0   0.0               NaN
# 6    02-27       4.0       2.0     79.0     22.0   0.0               NaN
# 7    02-28      73.0      12.0    123.0     28.0  40.0               NaN
# 8    03-01      33.0      18.0    143.0     33.0   6.0               NaN
# 9    03-02      20.0       4.0    158.0     32.0   0.0           19048.0
# 10   03-03      45.0      14.0    142.0     33.0   1.0           19877.0
# 11   03-04      28.0      10.0    154.0     34.0   0.0               NaN
# ...

# %%
#df.rename(index={2:'品牌'}, inplace=True)
df.rename({'小程序（??量）':'小程序（浏览量）'}, axis=1, inplace = True)
df.rename({'小程序（?客量）':'小程序（访客量）'}, axis=1, inplace = True)
df.rename({'淘?（??量）':'淘宝（浏览量）'}, axis=1, inplace = True)
df.rename({'淘?（?客量）':'淘宝（访客量）'}, axis=1, inplace = True)
df.rename({'掌上大?':'掌上大学'}, axis=1, inplace = True)

#df = df.drop(['Unnamed: 7'], axis = 1)
df = df.drop(['Unnamed: 8'], axis = 1)
df = df.drop(['Unnamed: 9'], axis = 1)
df = df.drop(['Unnamed: 10'], axis = 1)
df = df.drop(['Unnamed: 11'], axis = 1)
df = df.drop(['Unnamed: 12'], axis = 1)
df = df.drop(['Unnamed: 13'], axis = 1)
df = df.drop(['Unnamed: 14'], axis = 1)
df = df.drop(['Unnamed: 15'], axis = 1)
df = df.drop(['Unnamed: 16'], axis = 1)
df = df.drop(['Unnamed: 17'], axis = 1)
df = df.drop(['Unnamed: 18'], axis = 1)
df = df.drop(['Unnamed: 19'], axis = 1)
df = df.drop(['Unnamed: 20'], axis = 1)
df = df.drop(['Unnamed: 21'], axis = 1)
df = df.drop(['Unnamed: 22'], axis = 1)
df = df.drop(['Unnamed: 23'], axis = 1)

#df = df.drop(['???布篇?'], axis = 1)
df
# Out:
#         日期  小程序（浏览量）  小程序（访客量）  淘宝（浏览量）  淘宝（访客量）  掌上大学  总阅读数（博主文章的预估阅读数）  \
# 0    02-21      16.0       4.0    184.0     23.0   0.0               NaN
# 1    02-22       7.0       2.0    114.0     30.0   0.0               NaN
# 2    02-23       8.0       1.0    155.0     18.0   0.0               NaN
# 3    02-24      22.0       3.0    119.0     19.0   0.0               NaN
# 4    02-25       3.0       1.0    102.0     31.0   0.0               NaN
# 5    02-26      13.0       4.0    127.0     28.0   0.0               NaN
# 6    02-27       4.0       2.0     79.0     22.0   0.0               NaN
# 7    02-28      73.0      12.0    123.0     28.0  40.0               NaN
# 8    03-01      33.0      18.0    143.0     33.0   6.0               NaN
# 9    03-02      20.0       4.0    158.0     32.0   0.0           19048.0
# 10   03-03      45.0      14.0    142.0     33.0   1.0           19877.0
# 11   03-04      28.0      10.0    154.0     34.0   0.0               NaN
# ...

# %%
df_new = df.drop(['总阅读数（博主文章的预估阅读数）'], axis =1)
df_new.head()
# Out:
#       日期  小程序（浏览量）  小程序（访客量）  淘宝（浏览量）  淘宝（访客量）  掌上大学                  淘宝特点活动
# 0  02-21      16.0       4.0    184.0     23.0   0.0  2022.3.4~2022.3.8 ：情人节
# 1  02-22       7.0       2.0    114.0     30.0   0.0                     NaN
# 2  02-23       8.0       1.0    155.0     18.0   0.0                     NaN
# 3  02-24      22.0       3.0    119.0     19.0   0.0                     NaN
# 4  02-25       3.0       1.0    102.0     31.0   0.0                     NaN

# %%
plt.rcParams["figure.figsize"] = (10, 10)

df_new.plot(x='日期')

plt.legend(bbox_to_anchor=(1.02,1), loc=2, borderaxespad=0.)  #레전드값을 바깥에 그릴수 있게 하는 방법

# %%
grid_ndf = sns.pairplot(df) # 상관관계 보기

# %%
df.head()
# Out:
#       日期  小程序（浏览量）  小程序（访客量）  淘宝（浏览量）  淘宝（访客量）  掌上大学  总阅读数（博主文章的预估阅读数）  \
# 0  02-21      16.0       4.0    184.0     23.0   0.0               NaN
# 1  02-22       7.0       2.0    114.0     30.0   0.0               NaN
# 2  02-23       8.0       1.0    155.0     18.0   0.0               NaN
# 3  02-24      22.0       3.0    119.0     19.0   0.0               NaN
# 4  02-25       3.0       1.0    102.0     31.0   0.0               NaN
#
#                    淘宝特点活动
# 0  2022.3.4~2022.3.8 ：情人节
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %% [markdown]
# # Sheet4 - 매일마다의 전체 읽은 수만 그래프로

# %%
# 데이터 받아 오기
data_name = f"sheet4.csv"
data_name = pd.read_csv(data_name, encoding = "cp949", index_col = 0) #Encoding cp949는 못함,

# %%
df = data_name
df

# %%
#df.rename(index={2:'品牌'}, inplace=True)
df.rename({'_我是小?_?????':'_我是小陈_预估阅读数'}, axis=1, inplace = True)
df.rename({'艾思琦_?????':'艾思琦_预估阅读数'}, axis=1, inplace = True)
df.rename({'_金敏圭家??~?????':'_金敏圭家宝贝~预估阅读数'}, axis=1, inplace = True)
df.rename({'肥宅小蝴蝶_?????':'肥宅小蝴蝶_预估阅读数'}, axis=1, inplace = True)
df.rename({'小?栗子_?????':'小乔栗子_预估阅读数'}, axis=1, inplace = True)
df.rename({'?的可????_?????':'你的可爱鸭🦆_预估阅读数'}, axis=1, inplace = True)
df.rename({'泡一??_?????':'泡一条鱼_预估阅读数'}, axis=1, inplace = True)
df.rename({'??_?????':'鱼乐_预估阅读数'}, axis=1, inplace = True)
df.rename({'我?喝?茶_?????':'我爱喝奶茶_预估阅读数'}, axis=1, inplace = True)
df.rename({'起司姨太_?????':'起司姨太_预估阅读数'}, axis=1, inplace = True)
df.rename({'泡泡kiki_?????':'泡泡kiki_预估阅读数'}, axis=1, inplace = True)
df.rename({'艾思琦_?????.1':'艾思琦_预估阅读数'}, axis=1, inplace = True)
df.rename({'?猪少女不吃?_?????':'胖猪少女不吃鱼_预估阅读数'}, axis=1, inplace = True)
df.rename({'不吃?花的阿喜_?????':'不吃葱花的阿喜_预估阅读数'}, axis=1, inplace = True)
#df.rename({'':''}, axis=1, inplace = True)

df = df.drop(['Unnamed: 15'], axis = 1)
#df = df.drop(['Unnamed: 7'], axis = 1)

# %%
df

# %%
#df = df.drop(df.index[7:])

# %%
df = df.transpose()
df
