# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# 모든 데이터를 볼 수 있는 ( head랑 tail만 보여주는게 아니라, 다 보여주는 방법)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
## 중국어 폰트 설정 하는 방법

import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False
f_path = "C:\Windows\Fonts/simhei.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# 폰트를 선명하게 하기
# retina설정
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %%
data_name = f"NEW(1).csv"
df = pd.read_csv(data_name) #Encoding cp949는 못함
df
# Out:
#       序号      平台              ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片  \
# 0      1     小红书            甜崽小睿  11000       NaN  100  NaN  1.0     2
# 1      2     小红书            小乔栗子  35000       NaN  100  1.0  NaN     2
# 2      3     小红书       Yuqkoq77   13000       NaN  100  NaN  1.0     2
# 3      4     小红书             波伏瓦    391       NaN  100  NaN  1.0     1
# 4      5     小红书             瘦三斤      1       NaN  100  NaN  1.0     1
# 5      6     小红书       UKNO0000Y     21       NaN  100  NaN  1.0     1
# 6      7     小红书             大橙纸    252       NaN  100  NaN  1.0     1
# 7      8     小红书          明天不熬夜了    248       NaN  100  NaN  1.0     1
# 8      9     小红书          聪明的小刘刘    398       NaN  100  NaN  1.0     1
# 9     10  小红书/抖音           猪场老板   12000       NaN  100  1.0  NaN     2
# 10    11     小红书           苗苗布丁冻  12000       NaN  100  NaN  1.0     2
# 11    12     小红书             燃燃_    723       NaN  100  NaN  1.0     1
# ...

# %%
df = df.drop(["序号"], axis=1)
df = df.drop(["图文链接"], axis=1)
df = df.drop(["Unnamed: 10"], axis=1)
df = df.drop(["Unnamed: 11"], axis=1)
df = df.drop(["Unnamed: 12"], axis=1)
df = df.drop(["Unnamed: 13"], axis=1)
df = df.drop(["Unnamed: 14"], axis=1)
df = df.drop(["Unnamed: 15"], axis=1)
df = df.drop(["Unnamed: 16"], axis=1)
df = df.drop(["Unnamed: 17"], axis=1)

# %%
df
# Out:
#          平台              ID    粉丝数      赞藏总数   价钱   视频   图文  眼膜/片
# 0       小红书            甜崽小睿  11000       NaN  100  NaN  1.0     2
# 1       小红书            小乔栗子  35000       NaN  100  1.0  NaN     2
# 2       小红书       Yuqkoq77   13000       NaN  100  NaN  1.0     2
# 3       小红书             波伏瓦    391       NaN  100  NaN  1.0     1
# 4       小红书             瘦三斤      1       NaN  100  NaN  1.0     1
# 5       小红书       UKNO0000Y     21       NaN  100  NaN  1.0     1
# 6       小红书             大橙纸    252       NaN  100  NaN  1.0     1
# 7       小红书          明天不熬夜了    248       NaN  100  NaN  1.0     1
# 8       小红书          聪明的小刘刘    398       NaN  100  NaN  1.0     1
# 9    小红书/抖音           猪场老板   12000       NaN  100  1.0  NaN     2
# 10      小红书           苗苗布丁冻  12000       NaN  100  NaN  1.0     2
# 11      小红书             燃燃_    723       NaN  100  NaN  1.0     1
# 12      小红书           芋圆超爱吃  11000       NaN  100  NaN  1.0     1
# ...

# %%
df.columns =['平台', 'ID', '粉丝数', '赞藏总数', '价钱', '视频', '图文', '眼膜/片']
print(df.head())
print('\n')
# Out:
#     平台         ID    粉丝数  赞藏总数   价钱   视频   图文  眼膜/片
# 0  小红书       甜崽小睿  11000   NaN  100  NaN  1.0     2
# 1  小红书       小乔栗子  35000   NaN  100  1.0  NaN     2
# 2  小红书  Yuqkoq77   13000   NaN  100  NaN  1.0     2
# 3  小红书        波伏瓦    391   NaN  100  NaN  1.0     1
# 4  小红书        瘦三斤      1   NaN  100  NaN  1.0     1

# %%
print(df.info())
print('\n')
print(df.describe())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   平台      186 non-null    object
#  1   ID      186 non-null    object
#  2   粉丝数     186 non-null    int64
#  3   赞藏总数    131 non-null    float64
#  4   价钱      186 non-null    int64
#  5   视频      10 non-null     float64
#  6   图文      177 non-null    float64
#  7   眼膜/片    186 non-null    int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 11.8+ KB
# None
#
#
#                 粉丝数           赞藏总数          价钱         视频     图文        眼膜/片
# count    186.000000     131.000000  186.000000  10.000000  177.0  186.000000
# mean    7554.075269   37213.992366   58.010753   0.900000    1.0    1.698925
# std    12930.511388   95431.803672   80.463656   0.316228    0.0    0.802495
# min        1.000000     127.000000    0.000000   0.000000    1.0    1.000000
# ...

# %%
ndf = df[['粉丝数', '赞藏总数', '价钱', '视频', '图文', '眼膜/片']]
ndf
# Out:
#        粉丝数      赞藏总数   价钱   视频   图文  眼膜/片
# 0    11000       NaN  100  NaN  1.0     2
# 1    35000       NaN  100  1.0  NaN     2
# 2    13000       NaN  100  NaN  1.0     2
# 3      391       NaN  100  NaN  1.0     1
# 4        1       NaN  100  NaN  1.0     1
# 5       21       NaN  100  NaN  1.0     1
# 6      252       NaN  100  NaN  1.0     1
# 7      248       NaN  100  NaN  1.0     1
# 8      398       NaN  100  NaN  1.0     1
# 9    12000       NaN  100  1.0  NaN     2
# 10   12000       NaN  100  NaN  1.0     2
# 11     723       NaN  100  NaN  1.0     1
# 12   11000       NaN  100  NaN  1.0     1
# 13    1140       NaN  100  NaN  1.0     1
# 14   12000       NaN  100  NaN  1.0     1
# 15   20000       NaN  100  NaN  1.0     1
# 16   34000       NaN  200  NaN  1.0     1
# 17   14000       NaN  150  NaN  1.0     2
# 18   18000       NaN  180  NaN  1.0     1
# 19   49000       NaN  200  NaN  1.0     1
# 20   80000       NaN  300  NaN  1.0     2
# ...

# %%
# Nan 값 0으로 만들어주기
ndf = ndf.fillna(value=0)
ndf
# Out:
#        粉丝数      赞藏总数   价钱   视频   图文  眼膜/片
# 0    11000       0.0  100  0.0  1.0     2
# 1    35000       0.0  100  1.0  0.0     2
# 2    13000       0.0  100  0.0  1.0     2
# 3      391       0.0  100  0.0  1.0     1
# 4        1       0.0  100  0.0  1.0     1
# 5       21       0.0  100  0.0  1.0     1
# 6      252       0.0  100  0.0  1.0     1
# 7      248       0.0  100  0.0  1.0     1
# 8      398       0.0  100  0.0  1.0     1
# 9    12000       0.0  100  1.0  0.0     2
# 10   12000       0.0  100  0.0  1.0     2
# 11     723       0.0  100  0.0  1.0     1
# 12   11000       0.0  100  0.0  1.0     1
# 13    1140       0.0  100  0.0  1.0     1
# 14   12000       0.0  100  0.0  1.0     1
# 15   20000       0.0  100  0.0  1.0     1
# 16   34000       0.0  200  0.0  1.0     1
# 17   14000       0.0  150  0.0  1.0     2
# 18   18000       0.0  180  0.0  1.0     1
# 19   49000       0.0  200  0.0  1.0     1
# 20   80000       0.0  300  0.0  1.0     2
# ...

# %%
# matplotlib으로 그래프 그리기
# 종속 변수 Y인 " " 와 다른 변수 간의 선형관계를 그래프(산점도)로 확인

#ndf.plot(kind='scatter', x='粉丝数', y='판매량', c='coral', s=10, figsize=(10,5))
#ndf.plot(kind='scatter', x='赞藏总数', y='판매량', c='coral', s=10, figsize=(10,5))
#ndf.plot(kind='scatter', x='视频', y='판매량', c='coral', s=10, figsize=(10,5))
#ndf.plot(kind='scatter', x='图文', y='판매량', c='coral', s=10, figsize=(10,5))

#   ?는 선형관계가 보여 지지 않는다.

#plt.show()
#plt.close()

# %%
ndf.plot(kind='scatter', x='粉丝数', y='赞藏总数', c='coral', s=10, figsize=(5,3))
ndf.plot(kind='scatter', x='赞藏总数', y='眼膜/片', c='coral', s=10, figsize=(5,3))
ndf.plot(kind='scatter', x='视频', y='粉丝数', c='coral', s=10, figsize=(5,3))
ndf.plot(kind='scatter', x='图文', y='价钱', c='coral', s=10, figsize=(5,3))
#'粉丝数', '赞藏总数', '价钱', '视频', '图文', '眼膜/片'
# cylinders는 선형관계가 보여 지지 않는다.

plt.show()
plt.close()

# %%
# Seaborn 라이브러리의 regplot() 함수를 이용하여 두 변수에 대한 그래프(산점도) 그리기.

fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
sns.regplot(x='粉丝数', y='赞藏总数', data=ndf, ax=ax1)  # 회귀선 표시
sns.regplot(x='视频', y='赞藏总数', data=ndf, ax=ax2) # 회귀선 표시 안함 표시는 , fit_reg = False

plt.show()
plt.close()

# %%
# Seaborn 라이브러리의  pairplot() 함수를 사용하여 데이터프레임의 열을 두 개씩 짝을 지을 수 있는 모든 경우의 수에 대하여 두 변수 간의 산점도를 그린다.
# 앞에서는 각 변수에 대하여 하나씩 그래프를 그리는 것이지만, pairplot() 함수를 사용하면 한번에 모든 경우의 수에 대하여 그래프로 나타낼 수 있다.
# seaborn pariplot 으로 두 변수 간의 모든 경우의 수 그리기
# 컬럼으로 설정한 독립변수와 종속변수간의 모든 경우의 수를 그래프를 표시
grid_ndf = sns.pairplot(ndf)
plt.show()
plt.close()

# %%
X=ndf[['粉丝数']] # 독립 변수 X
y=ndf[['价钱']]    # 종속 변수 Y

# train data와 test data로 구분(7:3 비율)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,            # 독립 변수
                                                   y,             # 종속 변수
                                                   test_size=0.3,  # 검증 30%
                                                   random_state=10 # 랜덤 추출 값
                                                   )

print('train data 개수 : ', len(X_train))
print('testdata 개수 : ', len(X_test))
# Out:
# train data 개수 :  130
# testdata 개수 :  56

# %%
# sklearn 라이브러리에서 선형회귀분석 모듈 가져오기
from sklearn.linear_model import LinearRegression

# 단순 회귀 분석 모형 객체 생성
lr = LinearRegression()

# train data를 가지고 모형 학습
lr.fit(X_train, y_train)

# 학습을 마친 모형에 test data를 적용하여 결정계숙(R-제곱) 계산
r_square = lr.score(X_test, y_test)

print(r_square)
# Out:
# 0.5353656157594027

# %%
# 회귀식의 기울기
print('기울기 : ', lr.coef_)
print('\n')

# 회귀식의 y절편
print('y절편 :', lr.intercept_)
# Out:
# 기울기 :  [[0.00639225]]
#
#
# y절편 : [13.9476245]

# %%
# 모형에 전체 X 데이터를 입력하여 예측한 값 y_hat을 실제 값 y와 비교 
y_hat = lr.predict(X)

plt.figure(figsize=(8, 5))
ax1 = sns.distplot(y, hist=False, color = 'green',label="y")

ax2 = sns.distplot(y_hat, hist=False, label="y_hat", color ='red', ax=ax1)
plt.show()
plt.close()
# Out:
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\toyou\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
